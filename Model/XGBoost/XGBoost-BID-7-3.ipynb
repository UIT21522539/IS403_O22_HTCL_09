# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
# from keras.models import Sequential
# from keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Bidirectional

# %%
# Read the dataset
df = pd.read_csv('../Dataset/BID-Historical-Data_Group-9.csv',index_col='Date', parse_dates=True)
df.dropna() #Drop missing value
df = df.sort_values(by='Date', ascending=True)
df =df.reset_index(drop=True) #Reset the index
print(df)
# Out:
#           Price       Open       High        Low     Vol. Change %
# 0     25,141.50  24,950.20  25,332.90  24,950.20    1.45M    1.08%
# 1     25,715.50  25,332.90  25,830.30  25,256.30    1.15M    2.28%
# 2     26,480.90  25,409.40  27,016.60  25,409.40    5.30M    2.98%
# 3     26,595.70  26,480.90  26,710.50  26,327.80    2.01M    0.43%
# 4     26,710.50  26,787.00  26,978.30  26,557.40    2.14M    0.43%
# ...         ...        ...        ...        ...      ...      ...
# 1308  48,900.00  49,400.00  49,400.00  48,550.00  763.20K   -0.61%
# 1309  49,100.00  49,000.00  49,200.00  48,600.00    1.23M    0.41%
# 1310  48,600.00  49,450.00  49,450.00  48,600.00    1.39M   -1.02%
# 1311  47,700.00  48,400.00  48,500.00  47,400.00    2.09M   -1.85%
# 1312  47,100.00  47,700.00  48,300.00  47,100.00    1.97M   -1.26%
#
# [1313 rows x 6 columns]

# %%
print(df.dtypes)
# Out:
# Price       object
# Open        object
# High        object
# Low         object
# Vol.        object
# Change %    object
# dtype: object

# %%
# Hàm chuyển đổi
def convert_str_to_number(str):
    return float(str.replace(',', ''))

def convert_change_to_number(change_str):
    return float(change_str.strip('%')) / 100

def convert_volume_to_number(volume_str):
    factor = {'K': 1000, 'M': 1000000, 'B': 1000000000}
    return int(float(volume_str[:-1]) * factor[volume_str[-1]]) if volume_str[-1] in factor else int(volume_str)

# Áp dụng hàm chuyển đổi cho các cột giá trị
df['Price'], df['Open'], df['High'], df['Low'] = [df[col].apply(convert_str_to_number) for col in ['Price', 'Open', 'High', 'Low']]
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df["Vol."] = df["Vol."].apply(convert_volume_to_number)

print(df)
df.describe()
# Out:
#         Price     Open     High      Low     Vol.  Change %
# 0     25141.5  24950.2  25332.9  24950.2  1450000    0.0108
# 1     25715.5  25332.9  25830.3  25256.3  1150000    0.0228
# 2     26480.9  25409.4  27016.6  25409.4  5300000    0.0298
# 3     26595.7  26480.9  26710.5  26327.8  2009999    0.0043
# 4     26710.5  26787.0  26978.3  26557.4  2140000    0.0043
# ...       ...      ...      ...      ...      ...       ...
# 1308  48900.0  49400.0  49400.0  48550.0   763200   -0.0061
# 1309  49100.0  49000.0  49200.0  48600.0  1230000    0.0041
# 1310  48600.0  49450.0  49450.0  48600.0  1390000   -0.0102
# 1311  47700.0  48400.0  48500.0  47400.0  2089999   -0.0185
# 1312  47100.0  47700.0  48300.0  47100.0  1970000   -0.0126
#
# [1313 rows x 6 columns]
#               Price          Open          High           Low          Vol.  \
# count   1313.000000   1313.000000   1313.000000   1313.000000  1.313000e+03
# mean   35290.396420  35290.707388  35805.167479  34820.149429  2.018955e+06
# std     6519.054229   6544.786381   6627.970793   6453.353467  1.446782e+06
# min    23419.500000  23419.500000  24108.300000  22958.500000  1.838000e+05
# 25%    30970.000000  30970.000000  31325.000000  30613.700000  1.090000e+06
# 50%    34120.000000  34110.600000  34625.000000  33635.800000  1.650000e+06
# 75%    39356.000000  39400.000000  39846.500000  38912.000000  2.460000e+06
# max    54400.000000  54400.000000  56700.000000  53500.000000  1.638000e+07
#
#           Change %
# count  1313.000000
# mean      0.000722
# std       0.021709
# min      -0.099300
# 25%      -0.009200
# 50%       0.000000
# 75%       0.012000
# max       0.070000

# %%
df1=df.reset_index()['Price']
df1
# Out:
# 0       25141.5
# 1       25715.5
# 2       26480.9
# 3       26595.7
# 4       26710.5
#          ...
# 1308    48900.0
# 1309    49100.0
# 1310    48600.0
# 1311    47700.0
# 1312    47100.0
# Name: Price, Length: 1313, dtype: float64

# %%
# 4. split the data into train and test
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# df1.shape
print(df1)
# Out:
# [[0.05558335]
#  [0.07411113]
#  [0.098817  ]
#  ...
#  [0.81278546]
#  [0.78373493]
#  [0.76436791]]

# %%
# 4. split the data into train and test
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size 

train_data = df1[0:train_size,:]
test_data = df1[train_size:len(df1),:1]

# %%
#Training process
# a. convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# b. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
print(X_train)
# Out:
# [[0.05558335 0.07411113 0.098817   ... 0.12722519 0.11487226 0.09511144]
#  [0.07411113 0.098817   0.10252255 ... 0.11487226 0.09511144 0.11363922]
#  [0.098817   0.10252255 0.10622811 ... 0.09511144 0.11363922 0.12846145]
#  ...
#  [0.22796598 0.22367296 0.20646859 ... 0.19358952 0.17783767 0.11337777]
#  [0.22367296 0.20646859 0.22651345 ... 0.17783767 0.11337777 0.14058843]
#  [0.20646859 0.22651345 0.232259   ... 0.11337777 0.14058843 0.15204726]]

# %%
# 8. Define GRU Model
model = xgb.XGBRegressor(
                        objective='reg:squarederror',
                        n_estimators=1000,
                        learning_rate=0.01,
                        max_depth=6,
                        subsample=0.8,
                        colsample_bytree=0.8)

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# 7. Dự báo dữ liệu test, val
y_pred=model.predict(X_test)
y_pred
# Out:
# array([0.54899037, 0.55767757, 0.57438153, 0.5662264 , 0.5766409 ,
#        0.5548623 , 0.5516085 , 0.5535647 , 0.55232406, 0.5508429 ,
#        0.5404749 , 0.5202927 , 0.5239284 , 0.5272357 , 0.5093962 ,
#        0.50883335, 0.49785337, 0.4887886 , 0.50043315, 0.47510222,
#        0.4612174 , 0.4557936 , 0.46840388, 0.46696514, 0.45701346,
#        0.4532083 , 0.4378265 , 0.47128022, 0.4778421 , 0.48231426,
#        0.4950539 , 0.4891838 , 0.48368415, 0.47745034, 0.4853758 ,
#        0.4840635 , 0.478167  , 0.46982065, 0.45729765, 0.45197418,
#        0.45535022, 0.43051255, 0.4491601 , 0.4501639 , 0.4604439 ,
#        0.45488024, 0.4634728 , 0.46395862, 0.46405643, 0.4572517 ,
#        0.45095694, 0.43246725, 0.44394293, 0.44335848, 0.43523923,
#        0.4287465 , 0.42476052, 0.42198855, 0.4203599 , 0.41450232,
#        0.42987207, 0.44235712, 0.44606036, 0.44120377, 0.45703244,
#        0.43966278, 0.42517158, 0.4373811 , 0.4361527 , 0.44285005,
#        0.43738553, 0.43923724, 0.50983894, 0.5038483 , 0.5042429 ,
#        0.520595  , 0.51300985, 0.4882307 , 0.5015932 , 0.48163995,
#        0.48514527, 0.49515778, 0.4979726 , 0.5217151 , 0.53108853,
#        0.512627  , 0.50431937, 0.5234507 , 0.5465177 , 0.5685603 ,
#        0.5598157 , 0.5495886 , 0.5481336 , 0.54855967, 0.54745674,
#        0.49682763, 0.5027735 , 0.52896684, 0.5301151 , 0.54302394,
#        0.529757  , 0.45563534, 0.46927857, 0.45969722, 0.45975563,
#        0.45937067, 0.45733348, 0.45728764, 0.4601372 , 0.4771726 ,
#        0.5104496 , 0.5370392 , 0.532159  , 0.53147256, 0.53143895,
#        0.49831972, 0.52066845, 0.52407676, 0.5144087 , 0.5053044 ,
#        0.47272056, 0.46697927, 0.46439806, 0.45791256, 0.46457785,
#        0.4475482 , 0.43964085, 0.440032  , 0.44024467, 0.44046324,
#        0.43623403, 0.3806459 , 0.4186404 , 0.36780018, 0.40022513,
#        0.39323112, 0.3960761 , 0.4009687 , 0.4086137 , 0.40561956,
#        0.39228702, 0.35857442, 0.34681514, 0.34845468, 0.34059408,
#        0.3348846 , 0.34490007, 0.33818552, 0.342486  , 0.38968992,
#        0.3401471 , 0.34728202, 0.3548539 , 0.37972283, 0.34424913,
#        0.377248  , 0.39582843, 0.4031067 , 0.4104709 , 0.4083937 ,
#        0.40852928, 0.40771016, 0.4180129 , 0.4223162 , 0.41863027,
#        0.42515332, 0.4256588 , 0.42213377, 0.41791874, 0.41951483,
#        0.4159943 , 0.42192665, 0.43115318, 0.42641535, 0.43483844,
#        0.44799265, 0.4465132 , 0.44784334, 0.46120042, 0.5113465 ,
#        0.50479895, 0.52390236, 0.53060824, 0.5299171 , 0.5137895 ,
#        0.48840544, 0.48555017, 0.49520445, 0.5149085 , 0.54709524,
#        0.54790485, 0.5481824 , 0.5484153 , 0.5474306 , 0.5505002 ,
#        0.55656296, 0.57298726, 0.5846759 , 0.5888707 , 0.62936103,
#        0.65881634, 0.6803926 , 0.67317957, 0.66670626, 0.66589886,
#        0.6850904 , 0.67935646, 0.6861614 , 0.6928449 , 0.6869939 ,
#        0.69210154, 0.69113606, 0.68684465, 0.67844903, 0.6826535 ,
#        0.68391645, 0.6772034 , 0.6759074 , 0.67692477, 0.67734265,
#        0.677727  , 0.6775024 , 0.6765806 , 0.675823  , 0.6752553 ,
#        0.6767257 , 0.6761959 , 0.67598045, 0.6772897 , 0.67807347,
#        0.6776529 , 0.67677116, 0.676015  , 0.67637837, 0.67693245,
#        0.67763484, 0.67623574, 0.6754395 , 0.6763426 , 0.6777254 ,
#        0.6783258 , 0.67844534, 0.6781639 , 0.67698145, 0.6759983 ,
#        0.6762451 , 0.6760776 , 0.676297  , 0.67625606, 0.6755246 ,
#        0.6758553 , 0.67546785, 0.6755902 , 0.6755483 , 0.6757327 ,
#        0.6751266 , 0.67560303, 0.675917  , 0.675721  , 0.6759813 ,
#        0.67606795, 0.6752029 , 0.6749466 , 0.67531204, 0.67574406,
#        0.6752159 , 0.6752471 , 0.6753731 , 0.67572224, 0.67588764,
#        0.675408  , 0.67614514, 0.67521185, 0.674853  , 0.6744653 ,
#        0.6752013 , 0.6737566 , 0.67366165, 0.6744161 , 0.67444557,
#        0.6744244 , 0.673863  , 0.6739115 , 0.673896  , 0.67497635,
#        0.6750832 , 0.6749515 , 0.67404574, 0.6739167 , 0.67419726,
#        0.6742444 , 0.6736379 , 0.6736488 ], dtype=float32)

# %%
# 12. inverse transform the scaled ytest data back to its original scale.
y_pred_ = scaler.inverse_transform(y_pred.reshape(-1,1))
y_test_ = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
# 12. Đánh giá độ chính xác thuật toán 
test_rmse = np.sqrt(np.mean((y_pred_ - y_test_)**2))
print('Testing RMSE:', test_rmse)

from sklearn.metrics import mean_absolute_error
test_mae = mean_absolute_error(y_test_, y_pred_)
print('Testing MAE:', test_mae)

from sklearn.metrics import mean_absolute_percentage_error
test_mape = mean_absolute_percentage_error(y_test_, y_pred_)
print('Testing MAPE:', test_mape)
# Out:
# Testing RMSE: 3932.295997992684
# Testing MAE: 3206.8939446459044
# Testing MAPE: 0.07008575572963925

# %%
#Dự đoán 30 ngày tiếp theo
x_input = test_data.reshape(1,-1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output = []
n_steps = time_step
i = 0
pred_days = 30
while(i < pred_days):
    
    if(len(temp_input) > time_step):
        
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1,-1)
        
        yhat = model.predict(x_input)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat.tolist())
        temp_input=temp_input[1:]
       
        lst_output.extend(yhat.tolist())
        i = i+1
        
    else:
        yhat = model.predict(x_input)
        
        temp_input.extend(yhat.tolist())
        lst_output.extend(yhat.tolist())
        
        i = i+1
        
print("Output of predicted next days: ", lst_output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 19
#      16 x_input = np.array(temp_input[1:])
#      17 x_input = x_input.reshape(1,-1)
# ---> 19 yhat = model.predict(x_input)
#      20 print("{} day output {}".format(i,yhat))
#      21 temp_input.extend(yhat.tolist())
#
# File c:\Users\mikey\Desktop\LSTM\venv\Lib\site-packages\xgboost\sklearn.py:1168, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1166 if self._can_use_inplace_predict():
#    1167     try:
# -> 1168         predts = self.get_booster().inplace_predict(
#    1169             data=X,
#    1170             iteration_range=iteration_range,
#    1171             predict_type="margin" if output_margin else "value",
#    1172             missing=self.missing,
#    1173             base_margin=base_margin,
#    1174             validate_features=validate_features,
#    1175         )
#    1176         if _is_cupy_array(predts):
#    1177             import cupy  # pylint: disable=import-error
#
# File c:\Users\mikey\Desktop\LSTM\venv\Lib\site-packages\xgboost\core.py:2428, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2424         raise TypeError(
#    2425             "`shape` attribute is required when `validate_features` is True."
#    2426         )
#    2427     if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# -> 2428         raise ValueError(
#    2429             f"Feature shape mismatch, expected: {self.num_features()}, "
#    2430             f"got {data.shape[1]}"
#    2431         )
#    2433 if _is_np_array_like(data):
#    2434     from .data import _ensure_np_dtype
#
# ValueError: Feature shape mismatch, expected: 100, got 393

# %%
y_pred = y_pred.reshape(-1,1)
y_pred = scaler.inverse_transform(y_pred)

print("Test data prediction:", y_pred.shape)
# Out:
# Test data prediction: (293, 1)

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,y_pred)
prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)-1+len(scaler.inverse_transform(np.array(lst_output).reshape(-1,1))), step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(np.array(lst_output).reshape(-1,1)))
plt.legend(['Train','Test','Predict','Predict30days'])
plt.show()

# %%
#Dự đoán 60 ngày tiếp theo
x_input = test_data[len(test_data)-time_step:].reshape(1,-1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output = []
n_steps = time_step
i = 0
pred_days = 60
while(i < pred_days):
    
    if(len(temp_input) > time_step):
        
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1,-1)
        
        yhat = model.predict(x_input)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat.tolist())
        temp_input=temp_input[1:]
       
        lst_output.extend(yhat.tolist())
        i = i+1
        
    else:
        yhat = model.predict(x_input)
        
        temp_input.extend(yhat.tolist())
        lst_output.extend(yhat.tolist())
        
        i = i+1
        
print("Output of predicted next days: ", lst_output)
# Out:
# 1 day output [0.62377155]
# 2 day output [0.5666614]
# 3 day output [0.49440202]
# 4 day output [0.42680192]
# 5 day output [0.36784804]
# 6 day output [0.35480964]
# 7 day output [0.3382799]
# 8 day output [0.31972638]
# 9 day output [0.3072199]
# 10 day output [0.293303]
# 11 day output [0.2809482]
# 12 day output [0.2766168]
# 13 day output [0.2663296]
# 14 day output [0.26063854]
# 15 day output [0.26435384]
# 16 day output [0.2610879]
# 17 day output [0.2633265]
# 18 day output [0.26111978]
# 19 day output [0.2617524]
# 20 day output [0.25874957]
# 21 day output [0.2589944]
# 22 day output [0.25969502]
# 23 day output [0.25783795]
# 24 day output [0.25696972]
# 25 day output [0.25649437]
# 26 day output [0.25119174]
# 27 day output [0.2507095]
# 28 day output [0.24999458]
# 29 day output [0.25026184]
# 30 day output [0.24826895]
# 31 day output [0.24747302]
# 32 day output [0.2471172]
# 33 day output [0.24803784]
# 34 day output [0.24751699]
# 35 day output [0.24702433]
# 36 day output [0.24287681]
# 37 day output [0.23662259]
# 38 day output [0.23292764]
# 39 day output [0.22990008]
# 40 day output [0.23247017]
# 41 day output [0.23307838]
# 42 day output [0.23565668]
# 43 day output [0.24123949]
# 44 day output [0.24413586]
# 45 day output [0.24467418]
# 46 day output [0.24442933]
# 47 day output [0.2430856]
# 48 day output [0.2429181]
# 49 day output [0.24193728]
# 50 day output [0.24227428]
# 51 day output [0.24475405]
# 52 day output [0.24445139]
# 53 day output [0.24520753]
# 54 day output [0.2465892]
# 55 day output [0.25132737]
# 56 day output [0.25880226]
# 57 day output [0.26211935]
# 58 day output [0.26612604]
# 59 day output [0.26501048]
# Output of predicted next days:  [0.6733382940292358, 0.6237715482711792, 0.5666614174842834, 0.4944020211696625, 0.4268019199371338, 0.3678480386734009, 0.35480964183807373, 0.3382799029350281, 0.3197263777256012, 0.30721989274024963, 0.2933030128479004, 0.2809481918811798, 0.27661681175231934, 0.2663295865058899, 0.2606385350227356, 0.26435384154319763, 0.26108789443969727, 0.263326495885849, 0.2611197829246521, 0.2617523968219757, 0.2587495744228363, 0.2589944005012512, 0.25969502329826355, 0.2578379511833191, 0.25696972012519836, 0.2564943730831146, 0.25119173526763916, 0.25070950388908386, 0.24999457597732544, 0.2502618432044983, 0.2482689470052719, 0.24747301638126373, 0.24711720645427704, 0.24803784489631653, 0.24751698970794678, 0.2470243275165558, 0.2428768128156662, 0.23662258684635162, 0.23292763531208038, 0.2299000769853592, 0.23247016966342926, 0.23307837545871735, 0.23565667867660522, 0.2412394881248474, 0.24413585662841797, 0.2446741759777069, 0.2444293349981308, 0.2430855929851532, 0.24291810393333435, 0.2419372797012329, 0.24227428436279297, 0.24475404620170593, 0.2444513887166977, 0.2452075332403183, 0.24658919870853424, 0.25132736563682556, 0.25880226492881775, 0.2621193528175354, 0.26612603664398193, 0.2650104761123657]

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index, y_pred)

prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)-1+len(scaler.inverse_transform(np.array(lst_output).reshape(-1,1))), step=1)
plt.plot(prediect_data_index, scaler.inverse_transform(np.array(lst_output).reshape(-1,1)))

plt.legend(['Train', 'Test', 'Predict', 'Predict60days'])
plt.show()

# %%
#Dự đoán 90 ngày tiếp theo
x_input = test_data[len(test_data)-time_step:].reshape(1,-1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output = []
n_steps = time_step
i = 0
pred_days = 90
while(i < pred_days):
    
    if(len(temp_input) > time_step):
        
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1,-1)
        
        yhat = model.predict(x_input)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat.tolist())
        temp_input=temp_input[1:]
       
        lst_output.extend(yhat.tolist())
        i = i+1
        
    else:
        yhat = model.predict(x_input)
        
        temp_input.extend(yhat.tolist())
        lst_output.extend(yhat.tolist())
        
        i = i+1
        
print("Output of predicted next days: ", lst_output)
# Out:
# 1 day output [0.62377155]
# 2 day output [0.5666614]
# 3 day output [0.49440202]
# 4 day output [0.42680192]
# 5 day output [0.36784804]
# 6 day output [0.35480964]
# 7 day output [0.3382799]
# 8 day output [0.31972638]
# 9 day output [0.3072199]
# 10 day output [0.293303]
# 11 day output [0.2809482]
# 12 day output [0.2766168]
# 13 day output [0.2663296]
# 14 day output [0.26063854]
# 15 day output [0.26435384]
# 16 day output [0.2610879]
# 17 day output [0.2633265]
# 18 day output [0.26111978]
# 19 day output [0.2617524]
# 20 day output [0.25874957]
# 21 day output [0.2589944]
# 22 day output [0.25969502]
# 23 day output [0.25783795]
# 24 day output [0.25696972]
# 25 day output [0.25649437]
# 26 day output [0.25119174]
# 27 day output [0.2507095]
# 28 day output [0.24999458]
# 29 day output [0.25026184]
# 30 day output [0.24826895]
# 31 day output [0.24747302]
# 32 day output [0.2471172]
# 33 day output [0.24803784]
# 34 day output [0.24751699]
# 35 day output [0.24702433]
# 36 day output [0.24287681]
# 37 day output [0.23662259]
# 38 day output [0.23292764]
# 39 day output [0.22990008]
# 40 day output [0.23247017]
# 41 day output [0.23307838]
# 42 day output [0.23565668]
# 43 day output [0.24123949]
# 44 day output [0.24413586]
# 45 day output [0.24467418]
# 46 day output [0.24442933]
# 47 day output [0.2430856]
# 48 day output [0.2429181]
# 49 day output [0.24193728]
# 50 day output [0.24227428]
# 51 day output [0.24475405]
# 52 day output [0.24445139]
# 53 day output [0.24520753]
# 54 day output [0.2465892]
# 55 day output [0.25132737]
# 56 day output [0.25880226]
# 57 day output [0.26211935]
# 58 day output [0.26612604]
# 59 day output [0.26501048]
# 60 day output [0.26662153]
# 61 day output [0.26718476]
# 62 day output [0.26844823]
# 63 day output [0.26874545]
# 64 day output [0.2685535]
# 65 day output [0.26718867]
# 66 day output [0.26687154]
# 67 day output [0.27136177]
# 68 day output [0.27185434]
# 69 day output [0.27302754]
# 70 day output [0.2745449]
# 71 day output [0.27607495]
# 72 day output [0.27679336]
# 73 day output [0.2769668]
# 74 day output [0.2770837]
# 75 day output [0.27882132]
# 76 day output [0.278741]
# 77 day output [0.278923]
# 78 day output [0.28144476]
# 79 day output [0.29149348]
# 80 day output [0.2990241]
# 81 day output [0.30757853]
# 82 day output [0.3232085]
# 83 day output [0.34767464]
# 84 day output [0.36206797]
# 85 day output [0.37142283]
# 86 day output [0.37570912]
# 87 day output [0.38274798]
# 88 day output [0.38293186]
# 89 day output [0.38797998]
# Output of predicted next days:  [0.6733382940292358, 0.6237715482711792, 0.5666614174842834, 0.4944020211696625, 0.4268019199371338, 0.3678480386734009, 0.35480964183807373, 0.3382799029350281, 0.3197263777256012, 0.30721989274024963, 0.2933030128479004, 0.2809481918811798, 0.27661681175231934, 0.2663295865058899, 0.2606385350227356, 0.26435384154319763, 0.26108789443969727, 0.263326495885849, 0.2611197829246521, 0.2617523968219757, 0.2587495744228363, 0.2589944005012512, 0.25969502329826355, 0.2578379511833191, 0.25696972012519836, 0.2564943730831146, 0.25119173526763916, 0.25070950388908386, 0.24999457597732544, 0.2502618432044983, 0.2482689470052719, 0.24747301638126373, 0.24711720645427704, 0.24803784489631653, 0.24751698970794678, 0.2470243275165558, 0.2428768128156662, 0.23662258684635162, 0.23292763531208038, 0.2299000769853592, 0.23247016966342926, 0.23307837545871735, 0.23565667867660522, 0.2412394881248474, 0.24413585662841797, 0.2446741759777069, 0.2444293349981308, 0.2430855929851532, 0.24291810393333435, 0.2419372797012329, 0.24227428436279297, 0.24475404620170593, 0.2444513887166977, 0.2452075332403183, 0.24658919870853424, 0.25132736563682556, 0.25880226492881775, 0.2621193528175354, 0.26612603664398193, 0.2650104761123657, 0.26662153005599976, 0.2671847641468048, 0.26844823360443115, 0.26874545216560364, 0.2685534954071045, 0.2671886682510376, 0.26687154173851013, 0.271361768245697, 0.27185434103012085, 0.27302753925323486, 0.274544894695282, 0.27607494592666626, 0.27679336071014404, 0.27696681022644043, 0.27708369493484497, 0.27882131934165955, 0.2787410020828247, 0.27892300486564636, 0.2814447581768036, 0.2914934754371643, 0.2990241050720215, 0.30757853388786316, 0.3232085108757019, 0.3476746380329132, 0.36206796765327454, 0.37142282724380493, 0.3757091164588928, 0.38274797797203064, 0.3829318583011627, 0.38797998428344727]

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index, y_pred)

prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)-1+len(scaler.inverse_transform(np.array(lst_output).reshape(-1,1))), step=1)
plt.plot(prediect_data_index, scaler.inverse_transform(np.array(lst_output).reshape(-1,1)))

plt.legend(['Train', 'Test', 'Predict', 'Predict90days'])
plt.show()
