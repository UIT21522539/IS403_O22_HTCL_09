# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_csv('../../Dataset/ACB-Historical-Data_Group-9.csv')
df1=df.reset_index()['Price']

# %%
# 3. Chuyển các giá trị trong cột về number
def convert_volume_to_number(volume_str):
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    elif volume_str[-1] == 'B':
        return int(float(volume_str[:-1]) * 1000000000)
    else:
        return int(volume_str)
    
# Áp dụng hàm chuyển đổi cho cột "Vol."
df["Vol."] = df["Vol."].apply(convert_volume_to_number)

# Hàm chuyển đổi "Change %" từ chuỗi sang số
def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%')) / 100
    return new_change

# Áp dụng hàm chuyển đổi cho cột "Change %"
df["Change %"] = df["Change %"].apply(convert_change_to_number)

# Hàm chuyển giá từ chuỗi sang số
def convert_str_to_number(str):
    return float(str.replace(',', ''))

# Áp dụng hàm chuyển đổi cho các cột giá trị
df['Price'] = df['Price'].apply(convert_str_to_number)
df['Open'] = df['Open'].apply(convert_str_to_number)
df['High'] = df['High'].apply(convert_str_to_number)
df['Low'] = df['Low'].apply(convert_str_to_number)

# %%
df1=df.reset_index()['Price']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.9 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Define GRU Model

model = Sequential()
model.add(GRU(64, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 28s 357ms/step - loss: 0.0802 - val_loss: 0.0067
# Epoch 2/100
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0141 - val_loss: 0.0279
# Epoch 3/100
# 17/17 [==============================] - 2s 94ms/step - loss: 0.0062 - val_loss: 0.0028
# Epoch 4/100
# 17/17 [==============================] - 2s 127ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 5/100
# 17/17 [==============================] - 2s 129ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 6/100
# 17/17 [==============================] - 2s 135ms/step - loss: 7.4267e-04 - val_loss: 0.0013
# Epoch 7/100
# 17/17 [==============================] - 2s 121ms/step - loss: 6.5848e-04 - val_loss: 0.0014
# Epoch 8/100
# 17/17 [==============================] - 2s 113ms/step - loss: 6.2813e-04 - val_loss: 0.0013
# Epoch 9/100
# 17/17 [==============================] - 2s 102ms/step - loss: 6.1160e-04 - val_loss: 0.0013
# Epoch 10/100
# 17/17 [==============================] - 2s 118ms/step - loss: 5.9943e-04 - val_loss: 0.0013
# Epoch 11/100
# 17/17 [==============================] - 2s 106ms/step - loss: 5.8322e-04 - val_loss: 0.0013
# Epoch 12/100
# 17/17 [==============================] - 2s 144ms/step - loss: 5.7235e-04 - val_loss: 0.0013
# Epoch 13/100
# 17/17 [==============================] - 2s 113ms/step - loss: 5.6081e-04 - val_loss: 0.0013
# Epoch 14/100
# 17/17 [==============================] - 2s 124ms/step - loss: 5.4743e-04 - val_loss: 0.0013
# Epoch 15/100
# 17/17 [==============================] - 2s 126ms/step - loss: 5.4489e-04 - val_loss: 0.0013
# Epoch 16/100
# 17/17 [==============================] - 2s 126ms/step - loss: 5.2918e-04 - val_loss: 0.0013
# Epoch 17/100
# 17/17 [==============================] - 2s 141ms/step - loss: 5.3231e-04 - val_loss: 0.0013
# Epoch 18/100
# 17/17 [==============================] - 5s 292ms/step - loss: 5.1794e-04 - val_loss: 0.0013
# Epoch 19/100
# 17/17 [==============================] - 3s 170ms/step - loss: 5.0810e-04 - val_loss: 0.0013
# Epoch 20/100
# 17/17 [==============================] - 2s 109ms/step - loss: 5.0105e-04 - val_loss: 0.0013
# Epoch 21/100
# 17/17 [==============================] - 2s 97ms/step - loss: 4.9671e-04 - val_loss: 0.0013
# Epoch 22/100
# 17/17 [==============================] - 3s 212ms/step - loss: 4.9533e-04 - val_loss: 0.0014
# Epoch 23/100
# 17/17 [==============================] - 3s 155ms/step - loss: 4.8444e-04 - val_loss: 0.0013
# Epoch 24/100
# 17/17 [==============================] - 2s 125ms/step - loss: 4.8230e-04 - val_loss: 0.0013
# Epoch 25/100
# 17/17 [==============================] - 2s 101ms/step - loss: 4.7417e-04 - val_loss: 0.0013
# Epoch 26/100
# 17/17 [==============================] - 2s 138ms/step - loss: 4.7580e-04 - val_loss: 0.0013
# Epoch 27/100
# 17/17 [==============================] - 2s 114ms/step - loss: 4.6718e-04 - val_loss: 0.0013
# Epoch 28/100
# 17/17 [==============================] - 2s 93ms/step - loss: 4.6874e-04 - val_loss: 0.0013
# Epoch 29/100
# 17/17 [==============================] - 2s 128ms/step - loss: 4.6173e-04 - val_loss: 0.0013
# Epoch 30/100
# 17/17 [==============================] - 3s 161ms/step - loss: 4.5451e-04 - val_loss: 0.0013
# Epoch 31/100
# 17/17 [==============================] - 2s 97ms/step - loss: 4.5355e-04 - val_loss: 0.0013
# Epoch 32/100
# 17/17 [==============================] - 2s 116ms/step - loss: 4.5058e-04 - val_loss: 0.0013
# Epoch 33/100
# 17/17 [==============================] - 2s 136ms/step - loss: 4.4777e-04 - val_loss: 0.0013
# Epoch 34/100
# 17/17 [==============================] - 2s 151ms/step - loss: 4.4124e-04 - val_loss: 0.0013
# Epoch 35/100
# 17/17 [==============================] - 3s 190ms/step - loss: 4.3711e-04 - val_loss: 0.0013
# Epoch 36/100
# 17/17 [==============================] - 3s 167ms/step - loss: 4.3973e-04 - val_loss: 0.0013
# Epoch 37/100
# 17/17 [==============================] - 3s 170ms/step - loss: 4.3199e-04 - val_loss: 0.0013
# Epoch 38/100
# 17/17 [==============================] - 2s 140ms/step - loss: 4.3368e-04 - val_loss: 0.0013
# Epoch 39/100
# 17/17 [==============================] - 2s 141ms/step - loss: 4.2835e-04 - val_loss: 0.0013
# Epoch 40/100
# 17/17 [==============================] - 2s 119ms/step - loss: 4.3015e-04 - val_loss: 0.0013
# Epoch 41/100
# 17/17 [==============================] - 2s 116ms/step - loss: 4.3620e-04 - val_loss: 0.0013
# Epoch 42/100
# 17/17 [==============================] - 2s 121ms/step - loss: 4.2355e-04 - val_loss: 0.0013
# Epoch 43/100
# 17/17 [==============================] - 2s 148ms/step - loss: 4.3329e-04 - val_loss: 0.0013
# Epoch 44/100
# 17/17 [==============================] - 2s 135ms/step - loss: 4.3070e-04 - val_loss: 0.0013
# Epoch 45/100
# 17/17 [==============================] - 2s 135ms/step - loss: 4.1697e-04 - val_loss: 0.0013
# Epoch 46/100
# 17/17 [==============================] - 3s 153ms/step - loss: 4.1932e-04 - val_loss: 0.0013
# Epoch 47/100
# 17/17 [==============================] - 2s 152ms/step - loss: 4.1415e-04 - val_loss: 0.0013
# Epoch 48/100
# 17/17 [==============================] - 2s 146ms/step - loss: 4.1479e-04 - val_loss: 0.0013
# Epoch 49/100
# 17/17 [==============================] - 2s 121ms/step - loss: 4.0851e-04 - val_loss: 0.0013
# Epoch 50/100
# 17/17 [==============================] - 2s 105ms/step - loss: 4.1105e-04 - val_loss: 0.0013
# Epoch 51/100
# 17/17 [==============================] - 2s 122ms/step - loss: 4.0890e-04 - val_loss: 0.0013
# Epoch 52/100
# 17/17 [==============================] - 2s 118ms/step - loss: 4.1332e-04 - val_loss: 0.0013
# Epoch 53/100
# 17/17 [==============================] - 2s 125ms/step - loss: 4.0685e-04 - val_loss: 0.0013
# Epoch 54/100
# 17/17 [==============================] - 2s 149ms/step - loss: 4.1060e-04 - val_loss: 0.0013
# Epoch 55/100
# 17/17 [==============================] - 2s 114ms/step - loss: 4.0499e-04 - val_loss: 0.0013
# Epoch 56/100
# 17/17 [==============================] - 3s 180ms/step - loss: 4.0671e-04 - val_loss: 0.0013
# Epoch 57/100
# 17/17 [==============================] - 2s 123ms/step - loss: 4.0085e-04 - val_loss: 0.0013
# Epoch 58/100
# 17/17 [==============================] - 2s 97ms/step - loss: 4.0777e-04 - val_loss: 0.0013
# Epoch 59/100
# 17/17 [==============================] - 2s 143ms/step - loss: 3.9437e-04 - val_loss: 0.0013
# Epoch 60/100
# 17/17 [==============================] - 2s 118ms/step - loss: 3.9423e-04 - val_loss: 0.0013
# Epoch 61/100
# 17/17 [==============================] - 2s 105ms/step - loss: 4.0449e-04 - val_loss: 0.0013
# Epoch 62/100
# 17/17 [==============================] - 2s 137ms/step - loss: 3.9973e-04 - val_loss: 0.0013
# Epoch 63/100
# 17/17 [==============================] - 2s 145ms/step - loss: 4.0118e-04 - val_loss: 0.0013
# Epoch 64/100
# 17/17 [==============================] - 3s 173ms/step - loss: 3.8976e-04 - val_loss: 0.0013
# Epoch 65/100
# 17/17 [==============================] - 3s 156ms/step - loss: 3.9101e-04 - val_loss: 0.0013
# Epoch 66/100
# 17/17 [==============================] - 3s 167ms/step - loss: 3.8983e-04 - val_loss: 0.0013
# Epoch 67/100
# 17/17 [==============================] - 2s 139ms/step - loss: 3.9422e-04 - val_loss: 0.0014
# Epoch 68/100
# 17/17 [==============================] - 2s 133ms/step - loss: 4.0577e-04 - val_loss: 0.0013
# Epoch 69/100
# 17/17 [==============================] - 2s 128ms/step - loss: 3.9885e-04 - val_loss: 0.0013
# Epoch 70/100
# 17/17 [==============================] - 3s 153ms/step - loss: 3.8444e-04 - val_loss: 0.0013
# Epoch 71/100
# 17/17 [==============================] - 2s 111ms/step - loss: 3.9238e-04 - val_loss: 0.0014
# Epoch 72/100
# 17/17 [==============================] - 2s 150ms/step - loss: 3.8649e-04 - val_loss: 0.0013
# Epoch 73/100
# 17/17 [==============================] - 2s 126ms/step - loss: 3.8403e-04 - val_loss: 0.0013
# Epoch 74/100
# 17/17 [==============================] - 2s 127ms/step - loss: 3.8534e-04 - val_loss: 0.0013
# Epoch 75/100
# 17/17 [==============================] - 2s 121ms/step - loss: 3.9112e-04 - val_loss: 0.0013
# Epoch 76/100
# 17/17 [==============================] - 3s 161ms/step - loss: 3.7945e-04 - val_loss: 0.0013
# Epoch 77/100
# 17/17 [==============================] - 3s 171ms/step - loss: 3.8062e-04 - val_loss: 0.0013
# Epoch 78/100
# 17/17 [==============================] - 2s 121ms/step - loss: 3.8037e-04 - val_loss: 0.0013
# Epoch 79/100
# 17/17 [==============================] - 2s 122ms/step - loss: 3.9434e-04 - val_loss: 0.0013
# Epoch 80/100
# 17/17 [==============================] - 2s 116ms/step - loss: 4.0292e-04 - val_loss: 0.0013
# Epoch 81/100
# 17/17 [==============================] - 3s 158ms/step - loss: 4.1208e-04 - val_loss: 0.0013
# Epoch 82/100
# 17/17 [==============================] - 3s 160ms/step - loss: 3.8962e-04 - val_loss: 0.0013
# Epoch 83/100
# 17/17 [==============================] - 3s 156ms/step - loss: 3.9052e-04 - val_loss: 0.0013
# Epoch 84/100
# 17/17 [==============================] - 3s 152ms/step - loss: 3.8923e-04 - val_loss: 0.0013
# Epoch 85/100
# 17/17 [==============================] - 3s 149ms/step - loss: 3.8658e-04 - val_loss: 0.0013
# Epoch 86/100
# 17/17 [==============================] - 2s 152ms/step - loss: 3.8624e-04 - val_loss: 0.0013
# Epoch 87/100
# 17/17 [==============================] - 2s 143ms/step - loss: 3.7589e-04 - val_loss: 0.0013
# Epoch 88/100
# 17/17 [==============================] - 2s 149ms/step - loss: 3.7496e-04 - val_loss: 0.0013
# Epoch 89/100
# 17/17 [==============================] - 3s 154ms/step - loss: 3.7538e-04 - val_loss: 0.0013
# Epoch 90/100
# 17/17 [==============================] - 3s 159ms/step - loss: 3.8789e-04 - val_loss: 0.0013
# Epoch 91/100
# 17/17 [==============================] - 2s 133ms/step - loss: 3.7155e-04 - val_loss: 0.0013
# Epoch 92/100
# 17/17 [==============================] - 2s 140ms/step - loss: 3.8168e-04 - val_loss: 0.0013
# Epoch 93/100
# 17/17 [==============================] - 3s 155ms/step - loss: 3.8133e-04 - val_loss: 0.0013
# Epoch 94/100
# 17/17 [==============================] - 3s 167ms/step - loss: 3.7169e-04 - val_loss: 0.0013
# Epoch 95/100
# 17/17 [==============================] - 2s 144ms/step - loss: 3.6946e-04 - val_loss: 0.0013
# Epoch 96/100
# 17/17 [==============================] - 2s 124ms/step - loss: 3.7690e-04 - val_loss: 0.0013
# Epoch 97/100
# 17/17 [==============================] - 2s 152ms/step - loss: 3.7149e-04 - val_loss: 0.0012
# Epoch 98/100
# 17/17 [==============================] - 2s 115ms/step - loss: 3.6755e-04 - val_loss: 0.0013
# Epoch 99/100
# 17/17 [==============================] - 2s 146ms/step - loss: 3.7025e-04 - val_loss: 0.0012
# Epoch 100/100
# 17/17 [==============================] - 2s 132ms/step - loss: 3.7433e-04 - val_loss: 0.0013

# %%
# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
# Out:
# 34/34 [==============================] - 5s 19ms/step
# 1/1 [==============================] - 0s 304ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y test
train_predict=scaler.inverse_transform(train_predict)
y_pred_=scaler.inverse_transform(y_pred)
y_pred_new = scaler.inverse_transform(y_pred.reshape(1, -1))
y_test_new = scaler.inverse_transform(np.array([y_test], dtype=np.float32))

# %%
# 12. Dự báo 30 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_30 = []
n_steps = 100
i = 0

while i < 30:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_30.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_30.extend(yhat.tolist())
        i = i + 1

# %%
# 13. Dự báo 60 ngày tiếp theo 

x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_60 = []
n_steps = 100
i = 0

while i < 60:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_60.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_60.extend(yhat.tolist())
        i = i + 1

# %%
# 14. Dự báo 90 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_90 = []
n_steps = 100
i = 0

while i < 90:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_90.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_90.extend(yhat.tolist())
        i = i + 1

# %%
# 15.Vẽ hình dự báo 30 ngày tiếp theo

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred_))
prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output_30))
plt.legend(['Train','Test','Predict','Predict30days'])
plt.show()

# %%
# 15.Vẽ hình dự báo 60 ngày tiếp theo

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred_))
prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+59, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output_60))
plt.legend(['Train','Test','Predict','Predict60days'])
plt.show()

# %%
# 16.Vẽ hình dự báo 90 ngày tiếp theo

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred_))
prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+89, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output_90))
plt.legend(['Train','Test','Predict','Predict90days'])
plt.show()

# %%
# 17.Đánh giá thuật toán



# Tính toán RMSE, MAE và MAPE trên tập test
test_score_rmse = np.sqrt(mean_squared_error(y_test_new, y_pred_new))
test_score_mape = mean_absolute_percentage_error(y_test_new, y_pred_new) * 100


print('RMSE', test_score_rmse)
print('MAPE', test_score_mape)
# Tính MAE (Mean Absolute Error)
test_mae = np.mean(np.abs(y_test_new - y_pred_new))
print('MAE:', test_mae)
# Out:
# RMSE 765.60284
# MAPE 1.5120253898203373
# MAE: 411.35483
