# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D,Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt
from keras.utils import plot_model

# %%
# 2. Đọc file csv và gắng index với giá Close
# Chuẩn bị dữ liệu
data = pd.read_csv('../../Dataset/ACB-Historical-Data_Group-9.csv', index_col='Date', parse_dates=True)

# %%
# 3. Chuyển các giá trị trong cột về number
# Hàm chuyển đổi
def convert_str_to_number(str):
    return float(str.replace(',', ''))

def convert_change_to_number(change_str):
    return float(change_str.strip('%')) / 100

def convert_volume_to_number(volume_str):
    factor = {'K': 1000, 'M': 1000000, 'B': 1000000000}
    return int(float(volume_str[:-1]) * factor[volume_str[-1]]) if volume_str[-1] in factor else int(volume_str)

# Áp dụng hàm chuyển đổi cho các cột giá trị
data['Price'], data['Open'], data['High'], data['Low'] = [data[col].apply(convert_str_to_number) for col in ['Price', 'Open', 'High', 'Low']]
data['Change %'] = data['Change %'].apply(convert_change_to_number)
data["Vol."] = data["Vol."].apply(convert_volume_to_number)

data.reset_index(drop=True, inplace=True)
data.head(10)
# Out:
#      Price     Open     High      Low      Vol.  Change %
# 0  11361.0  11285.2  11398.8  11171.6   3910000    0.0101
# 1  11512.4  11361.0  11550.3  11323.1   8240000    0.0133
# 2  11474.6  11512.4  11626.0  11398.8   6510000   -0.0033
# 3  11474.6  11436.7  11512.4  11361.0   3110000    0.0000
# 4  11550.3  11512.4  11626.0  11474.6   8720000    0.0066
# 5  11474.6  11512.4  11588.2  11436.7   3740000   -0.0066
# 6  11512.4  11474.6  11588.2  11436.7   2730000    0.0033
# 7  11701.8  11550.3  11701.8  11474.6   6610000    0.0165
# 8  11891.1  11777.5  12004.7  11701.8  14450000    0.0162
# 9  11929.0  11891.1  12118.4  11853.3   6160000    0.0032

# %%
# 4. Scaler data

# Sử dụng MinMaxScaler để chuẩn hóa dữ liệu
price = data['Price'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# %%
# 5. Chia train test
# Chia dữ liệu thành train và test
train_size = int(len(price_scaled) * 0.9)
test_size = len(price_scaled) - train_size
train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:]

# Hàm để tạo dataset
def create_dataset(dataset, time_series=1):
    X, Y = [], []
    for i in range(len(dataset) - time_series):
        X.append(dataset[i:i + time_series, 0])
        Y.append(dataset[i + time_series, 0])
    return np.array(X), np.array(Y)

# Sử dụng time_series để tạo tập huấn luyện và tập kiểm tra
time_series = 30
X_train, Y_train = create_dataset(train_data, time_series)
X_test, Y_test = create_dataset(test_data, time_series)

# Định hình lại X_train và X_test cho mô hình 
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Kiểm tra hình dạng của dữ liệu
print(f'X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}')
print(f'X_test shape: {X_test.shape}, Y_test shape: {Y_test.shape}')
# Out:
# X_train shape: (1147, 30, 1), Y_train shape: (1147,)
# X_test shape: (101, 30, 1), Y_test shape: (101,)

# %%
#6. Xây dựng mô hình và train mô hình
model = Sequential()

# Add convolutional layers

model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(time_series, 1)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=1, kernel_size=3, activation='relu'))

# Add global average pooling layer
model.add(GlobalAveragePooling1D())

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 4s 54ms/step - loss: 0.0784 - val_loss: 0.0667
# Epoch 2/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0084 - val_loss: 0.0125
# Epoch 3/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 4/100
# 18/18 [==============================] - 1s 30ms/step - loss: 0.0031 - val_loss: 0.0061
# Epoch 5/100
# 18/18 [==============================] - 1s 30ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 6/100
# 18/18 [==============================] - 1s 29ms/step - loss: 0.0032 - val_loss: 0.0050
# Epoch 7/100
# 18/18 [==============================] - 1s 30ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 8/100
# 18/18 [==============================] - 1s 37ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 9/100
# 18/18 [==============================] - 1s 32ms/step - loss: 0.0029 - val_loss: 0.0037
# Epoch 10/100
# 18/18 [==============================] - 1s 31ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 11/100
# 18/18 [==============================] - 1s 30ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 12/100
# 18/18 [==============================] - 1s 31ms/step - loss: 0.0031 - val_loss: 0.0076
# Epoch 13/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 14/100
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 15/100
# 18/18 [==============================] - 1s 32ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 16/100
# 18/18 [==============================] - 1s 34ms/step - loss: 0.0028 - val_loss: 0.0038
# Epoch 17/100
# 18/18 [==============================] - 1s 32ms/step - loss: 0.0029 - val_loss: 0.0064
# Epoch 18/100
# 18/18 [==============================] - 1s 45ms/step - loss: 0.0029 - val_loss: 0.0070
# Epoch 19/100
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 20/100
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 21/100
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 22/100
# 18/18 [==============================] - 1s 57ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 23/100
# 18/18 [==============================] - 1s 44ms/step - loss: 0.0028 - val_loss: 0.0064
# Epoch 24/100
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 25/100
# 18/18 [==============================] - 1s 43ms/step - loss: 0.0030 - val_loss: 0.0053
# Epoch 26/100
# 18/18 [==============================] - 1s 50ms/step - loss: 0.0028 - val_loss: 0.0081
# Epoch 27/100
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 28/100
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0027 - val_loss: 0.0041
# Epoch 29/100
# 18/18 [==============================] - 1s 38ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 30/100
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0027 - val_loss: 0.0082
# Epoch 31/100
# 18/18 [==============================] - 1s 34ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 32/100
# 18/18 [==============================] - 1s 35ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 33/100
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 34/100
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0025 - val_loss: 0.0057
# Epoch 35/100
# 18/18 [==============================] - 1s 43ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 36/100
# 18/18 [==============================] - 1s 45ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 37/100
# 18/18 [==============================] - 1s 49ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 38/100
# 18/18 [==============================] - 1s 48ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 39/100
# 18/18 [==============================] - 1s 48ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 40/100
# 18/18 [==============================] - 1s 48ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 41/100
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 42/100
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 43/100
# 18/18 [==============================] - 1s 49ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 44/100
# 18/18 [==============================] - 1s 46ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 45/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 46/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.0018 - val_loss: 0.0064
# Epoch 47/100
# 18/18 [==============================] - 1s 35ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 48/100
# 18/18 [==============================] - 1s 38ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 49/100
# 18/18 [==============================] - 1s 31ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 50/100
# 18/18 [==============================] - 0s 26ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 51/100
# 18/18 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 52/100
# 18/18 [==============================] - 0s 25ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 53/100
# 18/18 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 54/100
# 18/18 [==============================] - 1s 35ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 55/100
# 18/18 [==============================] - 1s 33ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 56/100
# 18/18 [==============================] - 1s 28ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 57/100
# 18/18 [==============================] - 0s 26ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 58/100
# 18/18 [==============================] - 0s 27ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 59/100
# 18/18 [==============================] - 0s 25ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 60/100
# 18/18 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 61/100
# 18/18 [==============================] - 0s 25ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 62/100
# 18/18 [==============================] - 0s 25ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 63/100
# 18/18 [==============================] - 0s 26ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 64/100
# 18/18 [==============================] - 0s 24ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 65/100
# 18/18 [==============================] - 1s 34ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 66/100
# 18/18 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 67/100
# 18/18 [==============================] - 0s 26ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 68/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 69/100
# 18/18 [==============================] - 1s 37ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 70/100
# 18/18 [==============================] - 1s 33ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 71/100
# 18/18 [==============================] - 1s 48ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 72/100
# 18/18 [==============================] - 1s 38ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 73/100
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 74/100
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 75/100
# 18/18 [==============================] - 1s 47ms/step - loss: 0.0014 - val_loss: 0.0039
# Epoch 76/100
# 18/18 [==============================] - 1s 34ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 77/100
# 18/18 [==============================] - 1s 38ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 78/100
# 18/18 [==============================] - 1s 38ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 79/100
# 18/18 [==============================] - 1s 35ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 80/100
# 18/18 [==============================] - 1s 32ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 81/100
# 18/18 [==============================] - 1s 32ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 82/100
# 18/18 [==============================] - 1s 38ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 83/100
# 18/18 [==============================] - 1s 33ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 84/100
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 85/100
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 86/100
# 18/18 [==============================] - 1s 41ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 87/100
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 88/100
# 18/18 [==============================] - 1s 42ms/step - loss: 9.9488e-04 - val_loss: 0.0024
# Epoch 89/100
# 18/18 [==============================] - 1s 38ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 90/100
# 18/18 [==============================] - 1s 48ms/step - loss: 9.7076e-04 - val_loss: 0.0016
# Epoch 91/100
# 18/18 [==============================] - 1s 37ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 92/100
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 93/100
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 94/100
# 18/18 [==============================] - 1s 49ms/step - loss: 9.8256e-04 - val_loss: 0.0014
# Epoch 95/100
# 18/18 [==============================] - 1s 53ms/step - loss: 9.7156e-04 - val_loss: 0.0020
# Epoch 96/100
# 18/18 [==============================] - 1s 45ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 97/100
# 18/18 [==============================] - 1s 52ms/step - loss: 9.9821e-04 - val_loss: 0.0018
# Epoch 98/100
# 18/18 [==============================] - 1s 45ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 99/100
# 18/18 [==============================] - 1s 50ms/step - loss: 9.9619e-04 - val_loss: 0.0013
# Epoch 100/100
# 18/18 [==============================] - 1s 55ms/step - loss: 9.3978e-04 - val_loss: 0.0015

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 28, 256)           1024
#
#  conv1d_1 (Conv1D)           (None, 26, 128)           98432
#
#  conv1d_2 (Conv1D)           (None, 24, 64)            24640
#
#  conv1d_3 (Conv1D)           (None, 22, 32)            6176
#
#  conv1d_4 (Conv1D)           (None, 20, 1)             97
#
#  global_average_pooling1d (  (None, 1)                 0
#  GlobalAveragePooling1D)
#
# =================================================================
# Total params: 130369 (509.25 KB)
# Trainable params: 130369 (509.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 7. Dự báo trên tập test
test_predict = model.predict(X_test)

test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 4/4 [==============================] - 1s 7ms/step

# %%
# 8. Dự báo giá trị 30 ngày trong tương lai
last_30_days = price_scaled[-30:]
next_30_days = []
for i in range(30):
    x = last_30_days[-time_series:].reshape(1, time_series, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat)
    last_30_days = np.append(last_30_days, y_hat, axis=0)

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

# print(next_30_days)
# Out:
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 425ms/step

# %%
# 9. Dự báo giá trị 60 ngày trong tương lai
last_60_days = price_scaled[-60:]
next_60_days = []
for i in range(60):
    x = last_60_days[-time_series:].reshape(1, time_series, 1)
    y_hat = model.predict(x)
    next_60_days.append(y_hat)
    last_60_days = np.append(last_60_days, y_hat, axis=0)

next_60_days = np.array(next_60_days).reshape(-1, 1)
next_60_days = scaler.inverse_transform(next_60_days)

# print(next_60_days)
# Out:
# 1/1 [==============================] - 1s 523ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 379ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 1s 532ms/step
# 1/1 [==============================] - 0s 459ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 484ms/step
# 1/1 [==============================] - 0s 292ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 362ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 509ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 1s 727ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 1s 879ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 1s 536ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 325ms/step

# %%
# 14. Dự báo 90 ngày tiếp theo

last_90_days = price_scaled[-90:]
next_90_days = []
for i in range(90):
    x = last_90_days[-time_series:].reshape(1, time_series, 1)
    y_hat = model.predict(x)
    next_90_days.append(y_hat)
    last_90_days = np.append(last_90_days, y_hat, axis=0)

next_90_days = np.array(next_90_days).reshape(-1, 1)
next_90_days = scaler.inverse_transform(next_90_days)

# print(next_90_days)
# Out:
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 364ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 279ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 141ms/step

# %%
test_predict_df = pd.DataFrame(test_predict)
test_predict_index = range(len(train_data)+time_series, len(train_data)+time_series+len(test_predict))
test_predict_df.index = test_predict_index

next_30_days_df = pd.DataFrame(next_30_days)
next_30_index = range(len(data), len(data)+len(next_30_days))
next_30_days_df.index = next_30_index

next_60_days_df = pd.DataFrame(next_60_days)
next_60_index = range(len(data), len(data)+len(next_60_days))
next_60_days_df.index = next_60_index

next_90_days_df = pd.DataFrame(next_90_days)
next_90_index = range(len(data), len(data)+len(next_90_days))
next_90_days_df.index = next_90_index

train_data_df = data[:train_size][['Price']]
test_data_df = data[train_size:train_size + test_size][['Price']]

# y_pred_=scaler.inverse_transform(test_predict)

# %%
#11. Vẽ đồ thị các giá trị từ train tới test và dự đoán 90 ngày sau
# plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_90_days_df, label='Next 90 days')
plt.plot(next_60_days_df, label='Next 60 days')
plt.plot(next_30_days_df, label='Next 30 days')
plt.legend()
plt.show()

# %%
#12. Đánh giá mô hình
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mae = mean_absolute_error(Y_test[0], test_predict[:, 0])
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0])

print('RMSE :', test_score_rmse)
print('MAE :', test_score_mae)
print('MAPE :', test_score_mape*100)
# Out:
# RMSE : 827.6391120465767
# MAE : 588.7711285581684
# MAPE : 2.1990922139657085
