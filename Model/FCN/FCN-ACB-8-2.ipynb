# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D,Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt
from keras.utils import plot_model

# %%
# 2. Đọc file csv và gắng index với giá Close
# Chuẩn bị dữ liệu
data = pd.read_csv('../../Dataset/ACB-Historical-Data_Group-9.csv', index_col='Date', parse_dates=True)

# %%
# 3. Chuyển các giá trị trong cột về number
# Hàm chuyển đổi
def convert_str_to_number(str):
    return float(str.replace(',', ''))

def convert_change_to_number(change_str):
    return float(change_str.strip('%')) / 100

def convert_volume_to_number(volume_str):
    factor = {'K': 1000, 'M': 1000000, 'B': 1000000000}
    return int(float(volume_str[:-1]) * factor[volume_str[-1]]) if volume_str[-1] in factor else int(volume_str)

# Áp dụng hàm chuyển đổi cho các cột giá trị
data['Price'], data['Open'], data['High'], data['Low'] = [data[col].apply(convert_str_to_number) for col in ['Price', 'Open', 'High', 'Low']]
data['Change %'] = data['Change %'].apply(convert_change_to_number)
data["Vol."] = data["Vol."].apply(convert_volume_to_number)

data.reset_index(drop=True, inplace=True)
data.head(10)
# Out:
#      Price     Open     High      Low      Vol.  Change %
# 0  11361.0  11285.2  11398.8  11171.6   3910000    0.0101
# 1  11512.4  11361.0  11550.3  11323.1   8240000    0.0133
# 2  11474.6  11512.4  11626.0  11398.8   6510000   -0.0033
# 3  11474.6  11436.7  11512.4  11361.0   3110000    0.0000
# 4  11550.3  11512.4  11626.0  11474.6   8720000    0.0066
# 5  11474.6  11512.4  11588.2  11436.7   3740000   -0.0066
# 6  11512.4  11474.6  11588.2  11436.7   2730000    0.0033
# 7  11701.8  11550.3  11701.8  11474.6   6610000    0.0165
# 8  11891.1  11777.5  12004.7  11701.8  14450000    0.0162
# 9  11929.0  11891.1  12118.4  11853.3   6160000    0.0032

# %%
# 4. Scaler data

# Sử dụng MinMaxScaler để chuẩn hóa dữ liệu
price = data['Price'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# %%
# 5. Chia train test
# Chia dữ liệu thành train và test
train_size = int(len(price_scaled) * 0.8)
test_size = len(price_scaled) - train_size
train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:]

# Hàm để tạo dataset
def create_dataset(dataset, time_series=1):
    X, Y = [], []
    for i in range(len(dataset) - time_series):
        X.append(dataset[i:i + time_series, 0])
        Y.append(dataset[i + time_series, 0])
    return np.array(X), np.array(Y)

# Sử dụng time_series để tạo tập huấn luyện và tập kiểm tra
time_series = 30
X_train, Y_train = create_dataset(train_data, time_series)
X_test, Y_test = create_dataset(test_data, time_series)

# Định hình lại X_train và X_test cho mô hình 
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Kiểm tra hình dạng của dữ liệu
print(f'X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}')
print(f'X_test shape: {X_test.shape}, Y_test shape: {Y_test.shape}')
# Out:
# X_train shape: (1016, 30, 1), Y_train shape: (1016,)
# X_test shape: (232, 30, 1), Y_test shape: (232,)

# %%
#6. Xây dựng mô hình và train mô hình
model = Sequential()

# Add convolutional layers

model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(time_series, 1)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=1, kernel_size=3, activation='relu'))

# Add global average pooling layer
model.add(GlobalAveragePooling1D())

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 16/16 [==============================] - 11s 113ms/step - loss: 0.0711 - val_loss: 0.0387
# Epoch 2/100
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0091 - val_loss: 0.0058
# Epoch 3/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 4/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 5/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 6/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 7/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 8/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 9/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 10/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 11/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 12/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 13/100
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0035 - val_loss: 0.0047
# Epoch 14/100
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 15/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 16/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 17/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 18/100
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 19/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 20/100
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 21/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 22/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 23/100
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 24/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 25/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 26/100
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0032 - val_loss: 0.0048
# Epoch 27/100
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 28/100
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 29/100
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 30/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0030 - val_loss: 0.0037
# Epoch 31/100
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 32/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 33/100
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 34/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 35/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 36/100
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 37/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 38/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0030 - val_loss: 0.0056
# Epoch 39/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 40/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 41/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 42/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 43/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0029 - val_loss: 0.0036
# Epoch 44/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 45/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 46/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 47/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 48/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 49/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 50/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 51/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 52/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0029 - val_loss: 0.0042
# Epoch 53/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 54/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 55/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 56/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 57/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 58/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 59/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 60/100
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 61/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 62/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0027 - val_loss: 0.0047
# Epoch 63/100
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 64/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 65/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0027 - val_loss: 0.0045
# Epoch 66/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 67/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 68/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 69/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 70/100
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 71/100
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 72/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 73/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 74/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0025 - val_loss: 0.0098
# Epoch 75/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 76/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 77/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 78/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 79/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 80/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 81/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 82/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 83/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0026 - val_loss: 0.0060
# Epoch 84/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 85/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 86/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 87/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 88/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 89/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 90/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 91/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 92/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 93/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 94/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 95/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 96/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 97/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 98/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 99/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 100/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0013 - val_loss: 0.0026

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (None, 28, 256)           1024
#
#  conv1d_11 (Conv1D)          (None, 26, 128)           98432
#
#  conv1d_12 (Conv1D)          (None, 24, 64)            24640
#
#  conv1d_13 (Conv1D)          (None, 22, 32)            6176
#
#  conv1d_14 (Conv1D)          (None, 20, 1)             97
#
#  global_average_pooling1d_2  (None, 1)                 0
#   (GlobalAveragePooling1D)
#
# =================================================================
# Total params: 130369 (509.25 KB)
# Trainable params: 130369 (509.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 7. Dự báo trên tập test
test_predict = model.predict(X_test)

test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 8/8 [==============================] - 0s 5ms/step

# %%
# 8. Dự báo giá trị 30 ngày trong tương lai
last_30_days = price_scaled[-30:]
next_30_days = []
for i in range(30):
    x = last_30_days[-time_series:].reshape(1, time_series, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat)
    last_30_days = np.append(last_30_days, y_hat, axis=0)

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

# print(next_30_days)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
# 9. Dự báo giá trị 60 ngày trong tương lai
last_60_days = price_scaled[-60:]
next_60_days = []
for i in range(60):
    x = last_60_days[-time_series:].reshape(1, time_series, 1)
    y_hat = model.predict(x)
    next_60_days.append(y_hat)
    last_60_days = np.append(last_60_days, y_hat, axis=0)

next_60_days = np.array(next_60_days).reshape(-1, 1)
next_60_days = scaler.inverse_transform(next_60_days)

# print(next_60_days)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
# 14. Dự báo 90 ngày tiếp theo

last_90_days = price_scaled[-90:]
next_90_days = []
for i in range(90):
    x = last_90_days[-time_series:].reshape(1, time_series, 1)
    y_hat = model.predict(x)
    next_90_days.append(y_hat)
    last_90_days = np.append(last_90_days, y_hat, axis=0)

next_90_days = np.array(next_90_days).reshape(-1, 1)
next_90_days = scaler.inverse_transform(next_90_days)

# print(next_90_days)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
test_predict_df = pd.DataFrame(test_predict)
test_predict_index = range(len(train_data)+time_series, len(train_data)+time_series+len(test_predict))
test_predict_df.index = test_predict_index

next_30_days_df = pd.DataFrame(next_30_days)
next_30_index = range(len(data), len(data)+len(next_30_days))
next_30_days_df.index = next_30_index

next_60_days_df = pd.DataFrame(next_60_days)
next_60_index = range(len(data), len(data)+len(next_60_days))
next_60_days_df.index = next_60_index

next_90_days_df = pd.DataFrame(next_90_days)
next_90_index = range(len(data), len(data)+len(next_90_days))
next_90_days_df.index = next_90_index

train_data_df = data[:train_size][['Price']]
test_data_df = data[train_size:train_size + test_size][['Price']]

# y_pred_=scaler.inverse_transform(test_predict)

# %%
#11. Vẽ đồ thị các giá trị từ train tới test và dự đoán 90 ngày sau
# plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_90_days_df, label='Next 90 days')
plt.plot(next_60_days_df, label='Next 60 days')
plt.plot(next_30_days_df, label='Next 30 days')
plt.legend()
plt.show()

# %%
#12. Đánh giá mô hình
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mae = mean_absolute_error(Y_test[0], test_predict[:, 0])
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0])

print('RMSE :', test_score_rmse)
print('MAE :', test_score_mae)
print('MAPE :', test_score_mape*100)
# Out:
# RMSE : 1111.246170909619
# MAE : 911.2206913389009
# MAPE : 3.6139020096585863
