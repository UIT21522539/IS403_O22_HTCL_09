# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt

# %%
# 2. Đọc file csv và gắng index với giá Close
# Chuẩn bị dữ liệu
data = pd.read_csv('../../Dataset/ACB-Historical-Data_Group 9.csv', index_col='Date', parse_dates=True)

# %%
# 3. Chuyển các giá trị trong cột về number
# Hàm chuyển đổi
def convert_str_to_number(str):
    return float(str.replace(',', ''))

def convert_change_to_number(change_str):
    return float(change_str.strip('%')) / 100

def convert_volume_to_number(volume_str):
    factor = {'K': 1000, 'M': 1000000, 'B': 1000000000}
    return int(float(volume_str[:-1]) * factor[volume_str[-1]]) if volume_str[-1] in factor else int(volume_str)

# Áp dụng hàm chuyển đổi cho các cột giá trị
data['Price'], data['Open'], data['High'], data['Low'] = [data[col].apply(convert_str_to_number) for col in ['Price', 'Open', 'High', 'Low']]
data['Change %'] = data['Change %'].apply(convert_change_to_number)
data["Vol."] = data["Vol."].apply(convert_volume_to_number)

data.reset_index(drop=True, inplace=True)
data.head(10)
# Out:
#      Price     Open     High      Low      Vol.  Change %
# 0  11361.0  11285.2  11398.8  11171.6   3910000    0.0101
# 1  11512.4  11361.0  11550.3  11323.1   8240000    0.0133
# 2  11474.6  11512.4  11626.0  11398.8   6510000   -0.0033
# 3  11474.6  11436.7  11512.4  11361.0   3110000    0.0000
# 4  11550.3  11512.4  11626.0  11474.6   8720000    0.0066
# 5  11474.6  11512.4  11588.2  11436.7   3740000   -0.0066
# 6  11512.4  11474.6  11588.2  11436.7   2730000    0.0033
# 7  11701.8  11550.3  11701.8  11474.6   6610000    0.0165
# 8  11891.1  11777.5  12004.7  11701.8  14450000    0.0162
# 9  11929.0  11891.1  12118.4  11853.3   6160000    0.0032

# %%
# 4. Scaler data

# Sử dụng MinMaxScaler để chuẩn hóa dữ liệu
price = data['Price'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# %%
# 5. Chia train test
# Chia dữ liệu thành train và test
train_size = int(len(price_scaled) * 0.8)
test_size = len(price_scaled) - train_size
train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:]

# Hàm để tạo dataset
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:i + look_back, 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Sử dụng look_back để tạo tập huấn luyện và tập kiểm tra
look_back = 30
X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

# Định hình lại X_train và X_test cho mô hình LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Kiểm tra hình dạng của dữ liệu
print(f'X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}')
print(f'X_test shape: {X_test.shape}, Y_test shape: {Y_test.shape}')
# Out:
# X_train shape: (1016, 30, 1), Y_train shape: (1016,)
# X_test shape: (232, 30, 1), Y_test shape: (232,)

# %%
#6. Xây dựng mô hình và train mô hình
model = Sequential()

# Add convolutional layers
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(look_back, 1)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=1, kernel_size=3, activation='relu'))

# Add global average pooling layer
model.add(GlobalAveragePooling1D())

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 16/16 [==============================] - 9s 107ms/step - loss: 0.0346 - val_loss: 0.0034
# Epoch 2/100
# 16/16 [==============================] - 1s 57ms/step - loss: 0.0051 - val_loss: 0.0026
# Epoch 3/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 4/100
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0038 - val_loss: 0.0049
# Epoch 5/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 6/100
# 16/16 [==============================] - 1s 78ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 7/100
# 16/16 [==============================] - 1s 65ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 8/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0036 - val_loss: 0.0061
# Epoch 9/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 10/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 11/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 12/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 13/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0033 - val_loss: 0.0053
# Epoch 14/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 15/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 16/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 17/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 18/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 19/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 20/100
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 21/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 22/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 23/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 24/100
# 16/16 [==============================] - 1s 65ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 25/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0030 - val_loss: 0.0064
# Epoch 26/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 27/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 28/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 29/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 30/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 31/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 32/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 33/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 34/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 35/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 36/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 37/100
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 38/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 39/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 40/100
# 16/16 [==============================] - 1s 69ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 41/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 42/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 43/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0028 - val_loss: 0.0037
# Epoch 44/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 45/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 46/100
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 47/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 48/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 49/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0028 - val_loss: 0.0094
# Epoch 50/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 51/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 52/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 53/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 54/100
# 16/16 [==============================] - 1s 68ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 55/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0030 - val_loss: 0.0083
# Epoch 56/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 57/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 58/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 59/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 60/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 61/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 62/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 63/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 64/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0021 - val_loss: 0.0047
# Epoch 65/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 66/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 67/100
# 16/16 [==============================] - 1s 68ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 68/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 69/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 70/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 71/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 72/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 73/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 74/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 75/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 76/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 77/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 78/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 79/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 80/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 81/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 82/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 83/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 84/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 85/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 86/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 87/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 88/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 89/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 90/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 91/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 92/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 93/100
# 16/16 [==============================] - 1s 57ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 94/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 95/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 96/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 97/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 98/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 99/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 100/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0013 - val_loss: 0.0013

# %%
# 7. Dự báo trên tập test
test_predict = model.predict(X_test)

test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 8/8 [==============================] - 0s 11ms/step

# %%
# 8. Dự báo giá trị 30 ngày trong tương lai
last_30_days = price_scaled[-30:]
next_30_days = []
for i in range(30):
    x = last_30_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat)
    last_30_days = np.append(last_30_days, y_hat, axis=0)

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

print(next_30_days)
# Out:
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 104ms/step
# [[27000.664]
#  [26033.654]
#  [25679.705]
#  [25956.756]
#  [26239.371]
#  [26299.533]
#  [26326.51 ]
#  [26371.57 ]
#  [26382.174]
#  [26337.514]
#  [26243.94 ]
#  [26114.75 ]
#  [25962.111]
#  [25803.258]
#  [25638.62 ]
#  [25439.13 ]
#  [25186.566]
#  [24875.06 ]
#  [24522.42 ]
#  [24338.766]
#  [24708.441]
#  [25384.434]
#  [25660.625]
#  [25554.824]
#  [25480.033]
#  [25470.549]
#  [25337.242]
#  [25098.06 ]
#  [24864.102]
#  [24664.883]]

# %%
# 9. Dự báo giá trị 60 ngày trong tương lai
last_60_days = price_scaled[-60:]
next_60_days = []
for i in range(60):
    x = last_60_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_60_days.append(y_hat)
    last_60_days = np.append(last_30_days, y_hat, axis=0)

next_60_days = np.array(next_60_days).reshape(-1, 1)
next_60_days = scaler.inverse_transform(next_60_days)

print(next_60_days)
# Out:
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# [[27000.664]
#  [24519.889]
#  [24308.21 ]
#  [24288.33 ]
#  [24286.46 ]
#  [24286.287]
#  [24286.271]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]]

# %%
#10. Dự báo giá trị 90 ngày trong tương lai
last_90_days = price_scaled[-60:]
next_90_days = []
for i in range(90):
    x = last_90_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_90_days.append(y_hat)
    last_90_days = np.append(last_30_days, y_hat, axis=0)

next_90_days = np.array(next_90_days).reshape(-1, 1)
next_90_days = scaler.inverse_transform(next_90_days)

print(next_60_days)
# Out:
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# [[27000.664]
#  [24519.889]
#  [24308.21 ]
#  [24288.33 ]
#  [24286.46 ]
#  [24286.287]
#  [24286.271]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]
#  [24286.268]]

# %%
test_predict_df = pd.DataFrame(test_predict)
test_predict_index = range(len(train_data)+look_back, len(train_data)+look_back+len(test_predict))
test_predict_df.index = test_predict_index

next_30_days_df = pd.DataFrame(next_30_days)
next_30_index = range(len(data), len(data)+len(next_30_days))
next_30_days_df.index = next_30_index

next_60_days_df = pd.DataFrame(next_60_days)
next_60_index = range(len(data), len(data)+len(next_60_days))
next_60_days_df.index = next_60_index

next_90_days_df = pd.DataFrame(next_90_days)
next_90_index = range(len(data), len(data)+len(next_90_days))
next_90_days_df.index = next_90_index

train_data_df = data[:train_size][['Price']]
test_data_df = data[train_size:train_size + test_size][['Price']]

# %%
#11. Vẽ đồ thị các giá trị từ train tới test và dự đoán 30 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_30_days_df, label='Next 30 days')
plt.legend()
plt.show()

# %%
#12. Vẽ đồ thị các giá trị từ train tới test và dự đoán 60 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_60_days_df, label='Next 60 days')
plt.legend()
plt.show()

# %%
#13. Vẽ đồ thị các giá trị từ train tới test và dự đoán 90 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_90_days_df, label='Next 90 days')
plt.legend()
plt.show()

# %%
#14. Đánh giá mô hình
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mae = mean_absolute_error(Y_test[0], test_predict[:, 0])
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0])

print('RMSE :', test_score_rmse)
print('MAE :', test_score_mae)
print('MAPE :', test_score_mape)
# Out:
# RMSE : 791.9841231330956
# MAE : 593.1706677667025
# MAPE : 0.023492051480585405
