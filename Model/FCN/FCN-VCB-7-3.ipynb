# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D,Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt
from keras.utils import plot_model

# %%
# 2. Đọc file csv và gắng index với giá Close
# Chuẩn bị dữ liệu
data = pd.read_csv('../../Dataset/VCB-Historical-Data_Group-9.csv', index_col='Date', parse_dates=True)

# %%
# 3. Chuyển các giá trị trong cột về number
# Hàm chuyển đổi
def convert_str_to_number(str):
    return float(str.replace(',', ''))

def convert_change_to_number(change_str):
    return float(change_str.strip('%')) / 100

def convert_volume_to_number(volume_str):
    factor = {'K': 1000, 'M': 1000000, 'B': 1000000000}
    return int(float(volume_str[:-1]) * factor[volume_str[-1]]) if volume_str[-1] in factor else int(volume_str)

# Áp dụng hàm chuyển đổi cho các cột giá trị
data['Price'], data['Open'], data['High'], data['Low'] = [data[col].apply(convert_str_to_number) for col in ['Price', 'Open', 'High', 'Low']]
data['Change %'] = data['Change %'].apply(convert_change_to_number)
data["Vol."] = data["Vol."].apply(convert_volume_to_number)

data.reset_index(drop=True, inplace=True)
data.head(10)
# Out:
#      Price     Open     High      Low     Vol.  Change %
# 0  47765.0  46844.0  47765.0  46690.0   910430    0.0281
# 1  48226.0  47765.0  48379.0  47765.0  1720000    0.0097
# 2  48379.0  48226.0  48994.0  47995.0  2009999    0.0032
# 3  48149.0  48456.0  48610.0  47535.0  1380000   -0.0048
# 4  48456.0  48149.0  48994.0  48072.0  2420000    0.0064
# 5  48226.0  47919.0  48379.0  47688.0  1270000   -0.0047
# 6  48072.0  47919.0  48149.0  47535.0  1300000   -0.0032
# 7  49762.0  48379.0  49762.0  48149.0  2800000    0.0352
# 8  50069.0  49915.0  50069.0  49531.0  2140000    0.0062
# 9  51451.0  50069.0  51451.0  49531.0  2900000    0.0276

# %%
# 4. Scaler data

# Sử dụng MinMaxScaler để chuẩn hóa dữ liệu
price = data['Price'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# %%
# 5. Chia train test
# Chia dữ liệu thành train và test
train_size = int(len(price_scaled) * 0.7)
test_size = len(price_scaled) - train_size
train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:]

# Hàm để tạo dataset
def create_dataset(dataset, time_series=1):
    X, Y = [], []
    for i in range(len(dataset) - time_series):
        X.append(dataset[i:i + time_series, 0])
        Y.append(dataset[i + time_series, 0])
    return np.array(X), np.array(Y)

# Sử dụng time_series để tạo tập huấn luyện và tập kiểm tra
time_series = 30
X_train, Y_train = create_dataset(train_data, time_series)
X_test, Y_test = create_dataset(test_data, time_series)

# Định hình lại X_train và X_test cho mô hình 
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Kiểm tra hình dạng của dữ liệu
print(f'X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}')
print(f'X_test shape: {X_test.shape}, Y_test shape: {Y_test.shape}')
# Out:
# X_train shape: (889, 30, 1), Y_train shape: (889,)
# X_test shape: (364, 30, 1), Y_test shape: (364,)

# %%
#6. Xây dựng mô hình và train mô hình
model = Sequential()

# Add convolutional layers

model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(time_series, 1)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=1, kernel_size=3, activation='relu'))

# Add global average pooling layer
model.add(GlobalAveragePooling1D())

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 3s 59ms/step - loss: 0.0483 - val_loss: 0.0390
# Epoch 2/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0097 - val_loss: 0.0168
# Epoch 3/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0076 - val_loss: 0.0116
# Epoch 4/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0072 - val_loss: 0.0063
# Epoch 5/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0069 - val_loss: 0.0036
# Epoch 6/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0071 - val_loss: 0.0117
# Epoch 7/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0072 - val_loss: 0.0055
# Epoch 8/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0070 - val_loss: 0.0045
# Epoch 9/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 10/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0065 - val_loss: 0.0079
# Epoch 11/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 12/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0066 - val_loss: 0.0042
# Epoch 13/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0068 - val_loss: 0.0113
# Epoch 14/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0071 - val_loss: 0.0033
# Epoch 15/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0066 - val_loss: 0.0067
# Epoch 16/100
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0062 - val_loss: 0.0126
# Epoch 17/100
# 14/14 [==============================] - 1s 50ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 18/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0061 - val_loss: 0.0055
# Epoch 19/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 20/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0053 - val_loss: 0.0028
# Epoch 21/100
# 14/14 [==============================] - 1s 48ms/step - loss: 0.0050 - val_loss: 0.0073
# Epoch 22/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.0051 - val_loss: 0.0189
# Epoch 23/100
# 14/14 [==============================] - 1s 46ms/step - loss: 0.0056 - val_loss: 0.0112
# Epoch 24/100
# 14/14 [==============================] - 1s 45ms/step - loss: 0.0047 - val_loss: 0.0033
# Epoch 25/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 26/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0041 - val_loss: 0.0056
# Epoch 27/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 28/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0032 - val_loss: 0.0155
# Epoch 29/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 30/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 31/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 32/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0031 - val_loss: 0.0125
# Epoch 33/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0040 - val_loss: 0.0082
# Epoch 34/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0029 - val_loss: 0.0036
# Epoch 35/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 36/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 37/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 38/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0030 - val_loss: 0.0037
# Epoch 39/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0027 - val_loss: 0.0083
# Epoch 40/100
# 14/14 [==============================] - 1s 49ms/step - loss: 0.0027 - val_loss: 0.0055
# Epoch 41/100
# 14/14 [==============================] - 1s 46ms/step - loss: 0.0025 - val_loss: 0.0069
# Epoch 42/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0026 - val_loss: 0.0131
# Epoch 43/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0032 - val_loss: 0.0103
# Epoch 44/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0025 - val_loss: 0.0094
# Epoch 45/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 46/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 47/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0029 - val_loss: 0.0105
# Epoch 48/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0027 - val_loss: 0.0055
# Epoch 49/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 50/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 51/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0026 - val_loss: 0.0132
# Epoch 52/100
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 53/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0031 - val_loss: 0.0112
# Epoch 54/100
# 14/14 [==============================] - 1s 48ms/step - loss: 0.0028 - val_loss: 0.0053
# Epoch 55/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 56/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 57/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0023 - val_loss: 0.0086
# Epoch 58/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 59/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 60/100
# 14/14 [==============================] - 1s 48ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 61/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0023 - val_loss: 0.0082
# Epoch 62/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 63/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 64/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 65/100
# 14/14 [==============================] - 1s 49ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 66/100
# 14/14 [==============================] - 1s 48ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 67/100
# 14/14 [==============================] - 1s 46ms/step - loss: 0.0025 - val_loss: 0.0032
# Epoch 68/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0025 - val_loss: 0.0088
# Epoch 69/100
# 14/14 [==============================] - 1s 51ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 70/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 71/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 72/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 73/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.0021 - val_loss: 0.0048
# Epoch 74/100
# 14/14 [==============================] - 1s 49ms/step - loss: 0.0020 - val_loss: 0.0047
# Epoch 75/100
# 14/14 [==============================] - 1s 49ms/step - loss: 0.0024 - val_loss: 0.0046
# Epoch 76/100
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0028 - val_loss: 0.0053
# Epoch 77/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 78/100
# 14/14 [==============================] - 1s 69ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 79/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0021 - val_loss: 0.0074
# Epoch 80/100
# 14/14 [==============================] - 1s 51ms/step - loss: 0.0023 - val_loss: 0.0046
# Epoch 81/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.0020 - val_loss: 0.0055
# Epoch 82/100
# 14/14 [==============================] - 1s 50ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 83/100
# 14/14 [==============================] - 1s 45ms/step - loss: 0.0020 - val_loss: 0.0055
# Epoch 84/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0034 - val_loss: 0.0132
# Epoch 85/100
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 86/100
# 14/14 [==============================] - 1s 50ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 87/100
# 14/14 [==============================] - 1s 67ms/step - loss: 0.0020 - val_loss: 0.0061
# Epoch 88/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 89/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 90/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 91/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 92/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 93/100
# 14/14 [==============================] - 1s 49ms/step - loss: 0.0019 - val_loss: 0.0036
# Epoch 94/100
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0019 - val_loss: 0.0045
# Epoch 95/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 96/100
# 14/14 [==============================] - 1s 50ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 97/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.0020 - val_loss: 0.0038
# Epoch 98/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 99/100
# 14/14 [==============================] - 1s 48ms/step - loss: 0.0021 - val_loss: 0.0054
# Epoch 100/100
# 14/14 [==============================] - 1s 50ms/step - loss: 0.0022 - val_loss: 0.0051

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 28, 256)           1024
#
#  conv1d_1 (Conv1D)           (None, 26, 128)           98432
#
#  conv1d_2 (Conv1D)           (None, 24, 64)            24640
#
#  conv1d_3 (Conv1D)           (None, 22, 32)            6176
#
#  conv1d_4 (Conv1D)           (None, 20, 1)             97
#
#  global_average_pooling1d (  (None, 1)                 0
#  GlobalAveragePooling1D)
#
# =================================================================
# Total params: 130369 (509.25 KB)
# Trainable params: 130369 (509.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 7. Dự báo trên tập test
test_predict = model.predict(X_test)

test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 12/12 [==============================] - 1s 11ms/step

# %%
# 8. Dự báo giá trị 30 ngày trong tương lai
last_30_days = price_scaled[-30:]
next_30_days = []
for i in range(30):
    x = last_30_days[-time_series:].reshape(1, time_series, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat)
    last_30_days = np.append(last_30_days, y_hat, axis=0)

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

# print(next_30_days)
# Out:
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 193ms/step

# %%
# 9. Dự báo giá trị 60 ngày trong tương lai
last_60_days = price_scaled[-60:]
next_60_days = []
for i in range(60):
    x = last_60_days[-time_series:].reshape(1, time_series, 1)
    y_hat = model.predict(x)
    next_60_days.append(y_hat)
    last_60_days = np.append(last_60_days, y_hat, axis=0)

next_60_days = np.array(next_60_days).reshape(-1, 1)
next_60_days = scaler.inverse_transform(next_60_days)

# print(next_60_days)
# Out:
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 81ms/step

# %%
# 14. Dự báo 90 ngày tiếp theo

last_90_days = price_scaled[-90:]
next_90_days = []
for i in range(90):
    x = last_90_days[-time_series:].reshape(1, time_series, 1)
    y_hat = model.predict(x)
    next_90_days.append(y_hat)
    last_90_days = np.append(last_90_days, y_hat, axis=0)

next_90_days = np.array(next_90_days).reshape(-1, 1)
next_90_days = scaler.inverse_transform(next_90_days)

# print(next_90_days)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
test_predict_df = pd.DataFrame(test_predict)
test_predict_index = range(len(train_data)+time_series, len(train_data)+time_series+len(test_predict))
test_predict_df.index = test_predict_index

next_30_days_df = pd.DataFrame(next_30_days)
next_30_index = range(len(data), len(data)+len(next_30_days))
next_30_days_df.index = next_30_index

next_60_days_df = pd.DataFrame(next_60_days)
next_60_index = range(len(data), len(data)+len(next_60_days))
next_60_days_df.index = next_60_index

next_90_days_df = pd.DataFrame(next_90_days)
next_90_index = range(len(data), len(data)+len(next_90_days))
next_90_days_df.index = next_90_index

train_data_df = data[:train_size][['Price']]
test_data_df = data[train_size:train_size + test_size][['Price']]

# y_pred_=scaler.inverse_transform(test_predict)

# %%
#11. Vẽ đồ thị các giá trị từ train tới test và dự đoán 90 ngày sau
# plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_90_days_df, label='Next 90 days')
plt.plot(next_60_days_df, label='Next 60 days')
plt.plot(next_30_days_df, label='Next 30 days')
plt.legend()
plt.show()

# %%
#12. Đánh giá mô hình
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mae = mean_absolute_error(Y_test[0], test_predict[:, 0])
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0])

print('RMSE :', test_score_rmse)
print('MAE :', test_score_mae)
print('MAPE :', test_score_mape*100)
# Out:
# RMSE : 3824.708807893235
# MAE : 3154.3828983516482
# MAPE : 3.607590326324651
