# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt

# %%
# 2. Đọc file csv và gắng index với giá Close
# Chuẩn bị dữ liệu
data = pd.read_csv('../../Dataset/VCB-Historical-Data_Group-9.csv', index_col='Date', parse_dates=True)

# %%
# 3. Chuyển các giá trị trong cột về number
# Hàm chuyển đổi
def convert_str_to_number(str):
    return float(str.replace(',', ''))

def convert_change_to_number(change_str):
    return float(change_str.strip('%')) / 100

def convert_volume_to_number(volume_str):
    factor = {'K': 1000, 'M': 1000000, 'B': 1000000000}
    return int(float(volume_str[:-1]) * factor[volume_str[-1]]) if volume_str[-1] in factor else int(volume_str)

# Áp dụng hàm chuyển đổi cho các cột giá trị
data['Price'], data['Open'], data['High'], data['Low'] = [data[col].apply(convert_str_to_number) for col in ['Price', 'Open', 'High', 'Low']]
data['Change %'] = data['Change %'].apply(convert_change_to_number)
data["Vol."] = data["Vol."].apply(convert_volume_to_number)

data.reset_index(drop=True, inplace=True)
data.head(10)
# Out:
#      Price     Open     High      Low     Vol.  Change %
# 0  47765.0  46844.0  47765.0  46690.0   910430    0.0281
# 1  48226.0  47765.0  48379.0  47765.0  1720000    0.0097
# 2  48379.0  48226.0  48994.0  47995.0  2009999    0.0032
# 3  48149.0  48456.0  48610.0  47535.0  1380000   -0.0048
# 4  48456.0  48149.0  48994.0  48072.0  2420000    0.0064
# 5  48226.0  47919.0  48379.0  47688.0  1270000   -0.0047
# 6  48072.0  47919.0  48149.0  47535.0  1300000   -0.0032
# 7  49762.0  48379.0  49762.0  48149.0  2800000    0.0352
# 8  50069.0  49915.0  50069.0  49531.0  2140000    0.0062
# 9  51451.0  50069.0  51451.0  49531.0  2900000    0.0276

# %%
# 4. Scaler data

# Sử dụng MinMaxScaler để chuẩn hóa dữ liệu
price = data['Price'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# %%
# 5. Chia train test
# Chia dữ liệu thành train và test
train_size = int(len(price_scaled) * 0.7)
test_size = len(price_scaled) - train_size
train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:]

# Hàm để tạo dataset
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:i + look_back, 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Sử dụng look_back để tạo tập huấn luyện và tập kiểm tra
look_back = 30
X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

# Định hình lại X_train và X_test cho mô hình LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Kiểm tra hình dạng của dữ liệu
print(f'X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}')
print(f'X_test shape: {X_test.shape}, Y_test shape: {Y_test.shape}')
# Out:
# X_train shape: (889, 30, 1), Y_train shape: (889,)
# X_test shape: (364, 30, 1), Y_test shape: (364,)

# %%
#6. Xây dựng mô hình và train mô hình
model = Sequential()

# Add convolutional layers
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(look_back, 1)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=1, kernel_size=3, activation='relu'))

# Add global average pooling layer
model.add(GlobalAveragePooling1D())

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 20s 233ms/step - loss: 0.0647 - val_loss: 0.0293
# Epoch 2/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0126 - val_loss: 0.0035
# Epoch 3/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0080 - val_loss: 0.0033
# Epoch 4/100
# 14/14 [==============================] - 1s 76ms/step - loss: 0.0066 - val_loss: 0.0056
# Epoch 5/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 6/100
# 14/14 [==============================] - 1s 76ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 7/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0061 - val_loss: 0.0077
# Epoch 8/100
# 14/14 [==============================] - 1s 69ms/step - loss: 0.0061 - val_loss: 0.0040
# Epoch 9/100
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0061 - val_loss: 0.0040
# Epoch 10/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0060 - val_loss: 0.0045
# Epoch 11/100
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0061 - val_loss: 0.0029
# Epoch 12/100
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 13/100
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0059 - val_loss: 0.0043
# Epoch 14/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 15/100
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 16/100
# 14/14 [==============================] - 2s 166ms/step - loss: 0.0057 - val_loss: 0.0036
# Epoch 17/100
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 18/100
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0054 - val_loss: 0.0032
# Epoch 19/100
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0056 - val_loss: 0.0081
# Epoch 20/100
# 14/14 [==============================] - 2s 114ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 21/100
# 14/14 [==============================] - 2s 109ms/step - loss: 0.0052 - val_loss: 0.0039
# Epoch 22/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0053 - val_loss: 0.0035
# Epoch 23/100
# 14/14 [==============================] - 2s 126ms/step - loss: 0.0053 - val_loss: 0.0092
# Epoch 24/100
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 25/100
# 14/14 [==============================] - 1s 69ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 26/100
# 14/14 [==============================] - 1s 69ms/step - loss: 0.0046 - val_loss: 0.0035
# Epoch 27/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 28/100
# 14/14 [==============================] - 2s 115ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 29/100
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0042 - val_loss: 0.0062
# Epoch 30/100
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0042 - val_loss: 0.0027
# Epoch 31/100
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0044 - val_loss: 0.0024
# Epoch 32/100
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0042 - val_loss: 0.0032
# Epoch 33/100
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0038 - val_loss: 0.0023
# Epoch 34/100
# 14/14 [==============================] - 1s 104ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 35/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 36/100
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 37/100
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 38/100
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0033 - val_loss: 0.0061
# Epoch 39/100
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0034 - val_loss: 0.0094
# Epoch 40/100
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0034 - val_loss: 0.0059
# Epoch 41/100
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 42/100
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 43/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 44/100
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0027 - val_loss: 0.0049
# Epoch 45/100
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 46/100
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0026 - val_loss: 0.0052
# Epoch 47/100
# 14/14 [==============================] - 1s 107ms/step - loss: 0.0027 - val_loss: 0.0036
# Epoch 48/100
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 49/100
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 50/100
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0027 - val_loss: 0.0053
# Epoch 51/100
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 52/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 53/100
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 54/100
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 55/100
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 56/100
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0023 - val_loss: 0.0041
# Epoch 57/100
# 14/14 [==============================] - 1s 107ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 58/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0029 - val_loss: 0.0086
# Epoch 59/100
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 60/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 61/100
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 62/100
# 14/14 [==============================] - 1s 66ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 63/100
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 64/100
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 65/100
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 66/100
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 67/100
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 68/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0024 - val_loss: 0.0054
# Epoch 69/100
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 70/100
# 14/14 [==============================] - 1s 109ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 71/100
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 72/100
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 73/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0021 - val_loss: 0.0043
# Epoch 74/100
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 75/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 76/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 77/100
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 78/100
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 79/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 80/100
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0019 - val_loss: 0.0058
# Epoch 81/100
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 82/100
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 83/100
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 84/100
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 85/100
# 14/14 [==============================] - 2s 113ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 86/100
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 87/100
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 88/100
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 89/100
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 90/100
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 91/100
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 92/100
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 93/100
# 14/14 [==============================] - 1s 67ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 94/100
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 95/100
# 14/14 [==============================] - 2s 138ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 96/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 97/100
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 98/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 99/100
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 100/100
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0017 - val_loss: 0.0017

# %%
# 7. Dự báo trên tập test
test_predict = model.predict(X_test)

test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 12/12 [==============================] - 7s 14ms/step

# %%
# 8. Dự báo giá trị 30 ngày trong tương lai
last_30_days = price_scaled[-30:]
next_30_days = []
for i in range(30):
    x = last_30_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat)
    last_30_days = np.append(last_30_days, y_hat, axis=0)

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

print(next_30_days)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 1s 739ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 227ms/step
# [[88013.805]
#  [87239.43 ]
#  [86741.47 ]
#  [86380.78 ]
#  [86196.63 ]
#  [86148.79 ]
#  [86274.99 ]
#  [86511.72 ]
#  [86636.06 ]
#  [86374.16 ]
#  [85916.6  ]
#  [85450.1  ]
#  [85054.67 ]
#  [84833.88 ]
#  [84591.77 ]
#  [84399.44 ]
#  [84236.766]
#  [83932.336]
#  [83651.94 ]
#  [83583.35 ]
#  [83796.43 ]
#  [83985.7  ]
#  [84076.914]
#  [84191.53 ]
#  [84262.336]
#  [84308.64 ]
#  [84283.4  ]
#  [84162.945]
#  [83926.19 ]
#  [83600.49 ]]

# %%
# 9. Dự báo giá trị 60 ngày trong tương lai
last_60_days = price_scaled[-60:]
next_60_days = []
for i in range(60):
    x = last_60_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_60_days.append(y_hat)
    last_60_days = np.append(last_30_days, y_hat, axis=0)

next_60_days = np.array(next_60_days).reshape(-1, 1)
next_60_days = scaler.inverse_transform(next_60_days)

print(next_60_days)
# Out:
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 450ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 273ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 121ms/step
# [[88013.805]
#  [83754.87 ]
#  [83146.95 ]
#  [83058.56 ]
#  [83045.7  ]
#  [83043.836]
#  [83043.57 ]
#  [83043.52 ]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]]

# %%
#10. Dự báo giá trị 90 ngày trong tương lai
last_90_days = price_scaled[-60:]
next_90_days = []
for i in range(90):
    x = last_90_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_90_days.append(y_hat)
    last_90_days = np.append(last_30_days, y_hat, axis=0)

next_90_days = np.array(next_90_days).reshape(-1, 1)
next_90_days = scaler.inverse_transform(next_90_days)

print(next_60_days)
# Out:
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 279ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 66ms/step
# [[88013.805]
#  [83754.87 ]
#  [83146.95 ]
#  [83058.56 ]
#  [83045.7  ]
#  [83043.836]
#  [83043.57 ]
#  [83043.52 ]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]
#  [83043.516]]

# %%
test_predict_df = pd.DataFrame(test_predict)
test_predict_index = range(len(train_data)+look_back, len(train_data)+look_back+len(test_predict))
test_predict_df.index = test_predict_index

next_30_days_df = pd.DataFrame(next_30_days)
next_30_index = range(len(data), len(data)+len(next_30_days))
next_30_days_df.index = next_30_index

next_60_days_df = pd.DataFrame(next_60_days)
next_60_index = range(len(data), len(data)+len(next_60_days))
next_60_days_df.index = next_60_index

next_90_days_df = pd.DataFrame(next_90_days)
next_90_index = range(len(data), len(data)+len(next_90_days))
next_90_days_df.index = next_90_index

train_data_df = data[:train_size][['Price']]
test_data_df = data[train_size:train_size + test_size][['Price']]

# %%
#11. Vẽ đồ thị các giá trị từ train tới test và dự đoán 30 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_30_days_df, label='Next 30 days')
plt.legend()
plt.show()

# %%
#12. Vẽ đồ thị các giá trị từ train tới test và dự đoán 60 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_60_days_df, label='Next 60 days')
plt.legend()
plt.show()

# %%
#13. Vẽ đồ thị các giá trị từ train tới test và dự đoán 90 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_90_days_df, label='Next 90 days')
plt.legend()
plt.show()

# %%
#14. Đánh giá mô hình
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mae = mean_absolute_error(Y_test[0], test_predict[:, 0])
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0])

print('RMSE :', test_score_rmse)
print('MAE :', test_score_mae)
print('MAPE :', test_score_mape)
# Out:
# RMSE : 2192.387310872349
# MAE : 1712.1799450549452
# MAPE : 0.0202824180445849
