# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt

# %%
# 2. Đọc file csv và gắng index với giá Close
# Chuẩn bị dữ liệu
data = pd.read_csv('../../Dataset/BID-Historical-Data_Group 9.csv', index_col='Date', parse_dates=True)

# %%
# 3. Chuyển các giá trị trong cột về number
# Hàm chuyển đổi
def convert_str_to_number(str):
    return float(str.replace(',', ''))

def convert_change_to_number(change_str):
    return float(change_str.strip('%')) / 100

def convert_volume_to_number(volume_str):
    factor = {'K': 1000, 'M': 1000000, 'B': 1000000000}
    return int(float(volume_str[:-1]) * factor[volume_str[-1]]) if volume_str[-1] in factor else int(volume_str)

# Áp dụng hàm chuyển đổi cho các cột giá trị
data['Price'], data['Open'], data['High'], data['Low'] = [data[col].apply(convert_str_to_number) for col in ['Price', 'Open', 'High', 'Low']]
data['Change %'] = data['Change %'].apply(convert_change_to_number)
data["Vol."] = data["Vol."].apply(convert_volume_to_number)

data.reset_index(drop=True, inplace=True)
data.head(10)
# Out:
#      Price     Open     High      Low     Vol.  Change %
# 0  25141.5  24950.2  25332.9  24950.2  1450000    0.0108
# 1  25715.5  25332.9  25830.3  25256.3  1150000    0.0228
# 2  26480.9  25409.4  27016.6  25409.4  5300000    0.0298
# 3  26595.7  26480.9  26710.5  26327.8  2009999    0.0043
# 4  26710.5  26787.0  26978.3  26557.4  2140000    0.0043
# 5  26021.7  26366.1  26557.4  25945.1  2280000   -0.0258
# 6  25753.8  26098.2  26098.2  25600.7  1430000   -0.0103
# 7  27169.7  26098.2  27169.7  25868.6  2130000    0.0550
# 8  27246.2  27016.6  27514.1  26940.1  3600000    0.0028
# 9  27705.4  27246.2  28088.1  26940.1  3330000    0.0169

# %%
# 4. Scaler data

# Sử dụng MinMaxScaler để chuẩn hóa dữ liệu
price = data['Price'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# %%
# 5. Chia train test
# Chia dữ liệu thành train và test
train_size = int(len(price_scaled) * 0.7)
test_size = len(price_scaled) - train_size
train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:]

# Hàm để tạo dataset
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:i + look_back, 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Sử dụng look_back để tạo tập huấn luyện và tập kiểm tra
look_back = 30
X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

# Định hình lại X_train và X_test cho mô hình LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Kiểm tra hình dạng của dữ liệu
print(f'X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}')
print(f'X_test shape: {X_test.shape}, Y_test shape: {Y_test.shape}')
# Out:
# X_train shape: (889, 30, 1), Y_train shape: (889,)
# X_test shape: (364, 30, 1), Y_test shape: (364,)

# %%
#6. Xây dựng mô hình và train mô hình
model = Sequential()

# Add convolutional layers
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(look_back, 1)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=1, kernel_size=3, activation='relu'))

# Add global average pooling layer
model.add(GlobalAveragePooling1D())

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 2s 30ms/step - loss: 0.0291 - val_loss: 0.0487
# Epoch 2/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0103 - val_loss: 0.0139
# Epoch 3/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0087 - val_loss: 0.0148
# Epoch 4/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0084 - val_loss: 0.0079
# Epoch 5/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0081 - val_loss: 0.0041
# Epoch 6/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0077 - val_loss: 0.0055
# Epoch 7/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0077 - val_loss: 0.0051
# Epoch 8/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0068 - val_loss: 0.0052
# Epoch 9/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0064 - val_loss: 0.0126
# Epoch 10/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0061 - val_loss: 0.0207
# Epoch 11/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0068
# Epoch 12/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 0.0134
# Epoch 13/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 14/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 15/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 16/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 17/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0051
# Epoch 18/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 19/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 20/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 21/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 22/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0045
# Epoch 23/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0123
# Epoch 24/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0035 - val_loss: 0.0104
# Epoch 25/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0069
# Epoch 26/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 27/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0053
# Epoch 28/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0071
# Epoch 29/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0027 - val_loss: 0.0044
# Epoch 30/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 31/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0048
# Epoch 32/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0067
# Epoch 33/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 34/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 35/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0023 - val_loss: 0.0044
# Epoch 36/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 37/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 38/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 39/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 40/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 41/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 42/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 43/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0021 - val_loss: 0.0052
# Epoch 44/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0023 - val_loss: 0.0059
# Epoch 45/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 46/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 47/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 48/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 0.0050
# Epoch 49/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0052
# Epoch 50/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 51/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 0.0039
# Epoch 52/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 53/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0020 - val_loss: 0.0073
# Epoch 54/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 0.0039
# Epoch 55/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 56/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 57/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0021 - val_loss: 0.0083
# Epoch 58/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 59/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 60/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 61/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 62/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 63/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 64/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 65/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0019 - val_loss: 0.0049
# Epoch 66/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 67/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 68/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 69/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 0.0061
# Epoch 70/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 71/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 72/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 73/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 74/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0018 - val_loss: 0.0070
# Epoch 75/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0019 - val_loss: 0.0050
# Epoch 76/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 77/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 78/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 79/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 0.0054
# Epoch 80/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 81/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 82/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 83/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 84/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 85/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 86/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 87/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 88/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0016 - val_loss: 0.0044
# Epoch 89/100
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 90/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0052
# Epoch 91/100
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 92/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 93/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0048
# Epoch 94/100
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0016 - val_loss: 0.0052
# Epoch 95/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 96/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 97/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 98/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 99/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0017 - val_loss: 0.0044
# Epoch 100/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0016 - val_loss: 0.0028

# %%
# 7. Dự báo trên tập test
test_predict = model.predict(X_test)

test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 12/12 [==============================] - 0s 4ms/step

# %%
# 8. Dự báo giá trị 30 ngày trong tương lai
last_30_days = price_scaled[-30:]
next_30_days = []
for i in range(30):
    x = last_30_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat)
    last_30_days = np.append(last_30_days, y_hat, axis=0)

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

print(next_30_days)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# [[47789.094]
#  [47471.97 ]
#  [47292.066]
#  [47249.76 ]
#  [47290.19 ]
#  [47481.062]
#  [47788.348]
#  [48170.2  ]
#  [48346.22 ]
#  [48080.145]
#  [47724.824]
#  [47340.5  ]
#  [46794.227]
#  [46313.977]
#  [46019.906]
#  [45883.15 ]
#  [45878.67 ]
#  [45847.137]
#  [45881.65 ]
#  [46155.613]
#  [46549.867]
#  [46669.19 ]
#  [46650.9  ]
#  [46649.55 ]
#  [46545.56 ]
#  [46349.75 ]
#  [46058.547]
#  [45667.926]
#  [45182.715]
#  [44670.656]]

# %%
# 9. Dự báo giá trị 60 ngày trong tương lai
last_60_days = price_scaled[-60:]
next_60_days = []
for i in range(60):
    x = last_60_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_60_days.append(y_hat)
    last_60_days = np.append(last_30_days, y_hat, axis=0)

next_60_days = np.array(next_60_days).reshape(-1, 1)
next_60_days = scaler.inverse_transform(next_60_days)

print(next_60_days)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# [[47789.094]
#  [45076.82 ]
#  [44283.957]
#  [44088.082]
#  [44039.69 ]
#  [44027.74 ]
#  [44024.785]
#  [44024.055]
#  [44023.875]
#  [44023.83 ]
#  [44023.82 ]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]]

# %%
#10. Dự báo giá trị 90 ngày trong tương lai
last_90_days = price_scaled[-60:]
next_90_days = []
for i in range(90):
    x = last_90_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_90_days.append(y_hat)
    last_90_days = np.append(last_30_days, y_hat, axis=0)

next_90_days = np.array(next_90_days).reshape(-1, 1)
next_90_days = scaler.inverse_transform(next_90_days)

print(next_60_days)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# [[47789.094]
#  [45076.82 ]
#  [44283.957]
#  [44088.082]
#  [44039.69 ]
#  [44027.74 ]
#  [44024.785]
#  [44024.055]
#  [44023.875]
#  [44023.83 ]
#  [44023.82 ]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]
#  [44023.816]]

# %%
test_predict_df = pd.DataFrame(test_predict)
test_predict_index = range(len(train_data)+look_back, len(train_data)+look_back+len(test_predict))
test_predict_df.index = test_predict_index

next_30_days_df = pd.DataFrame(next_30_days)
next_30_index = range(len(data), len(data)+len(next_30_days))
next_30_days_df.index = next_30_index

next_60_days_df = pd.DataFrame(next_60_days)
next_60_index = range(len(data), len(data)+len(next_60_days))
next_60_days_df.index = next_60_index

next_90_days_df = pd.DataFrame(next_90_days)
next_90_index = range(len(data), len(data)+len(next_90_days))
next_90_days_df.index = next_90_index

train_data_df = data[:train_size][['Price']]
test_data_df = data[train_size:train_size + test_size][['Price']]

# %%
#11. Vẽ đồ thị các giá trị từ train tới test và dự đoán 30 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_30_days_df, label='Next 30 days')
plt.legend()
plt.show()

# %%
#12. Vẽ đồ thị các giá trị từ train tới test và dự đoán 60 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_60_days_df, label='Next 60 days')
plt.legend()
plt.show()

# %%
#13. Vẽ đồ thị các giá trị từ train tới test và dự đoán 90 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_90_days_df, label='Next 90 days')
plt.legend()
plt.show()

# %%
#14. Đánh giá mô hình
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mae = mean_absolute_error(Y_test[0], test_predict[:, 0])
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0])

print('RMSE :', test_score_rmse)
print('MAE :', test_score_mae)
print('MAPE :', test_score_mape)
# Out:
# RMSE : 1636.2305560909708
# MAE : 1336.0777601304944
# MAPE : 0.03175949455167978
