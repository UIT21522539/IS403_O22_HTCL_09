# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt

# %%
# 2. Đọc file csv và gắng index với giá Close
# Chuẩn bị dữ liệu
data = pd.read_csv('../../Dataset/BID-Historical-Data_Group-9.csv', index_col='Date', parse_dates=True)

# %%
# 3. Chuyển các giá trị trong cột về number
# Hàm chuyển đổi
def convert_str_to_number(str):
    return float(str.replace(',', ''))

def convert_change_to_number(change_str):
    return float(change_str.strip('%')) / 100

def convert_volume_to_number(volume_str):
    factor = {'K': 1000, 'M': 1000000, 'B': 1000000000}
    return int(float(volume_str[:-1]) * factor[volume_str[-1]]) if volume_str[-1] in factor else int(volume_str)

# Áp dụng hàm chuyển đổi cho các cột giá trị
data['Price'], data['Open'], data['High'], data['Low'] = [data[col].apply(convert_str_to_number) for col in ['Price', 'Open', 'High', 'Low']]
data['Change %'] = data['Change %'].apply(convert_change_to_number)
data["Vol."] = data["Vol."].apply(convert_volume_to_number)

data.reset_index(drop=True, inplace=True)
data.head(10)
# Out:
#      Price     Open     High      Low     Vol.  Change %
# 0  25141.5  24950.2  25332.9  24950.2  1450000    0.0108
# 1  25715.5  25332.9  25830.3  25256.3  1150000    0.0228
# 2  26480.9  25409.4  27016.6  25409.4  5300000    0.0298
# 3  26595.7  26480.9  26710.5  26327.8  2009999    0.0043
# 4  26710.5  26787.0  26978.3  26557.4  2140000    0.0043
# 5  26021.7  26366.1  26557.4  25945.1  2280000   -0.0258
# 6  25753.8  26098.2  26098.2  25600.7  1430000   -0.0103
# 7  27169.7  26098.2  27169.7  25868.6  2130000    0.0550
# 8  27246.2  27016.6  27514.1  26940.1  3600000    0.0028
# 9  27705.4  27246.2  28088.1  26940.1  3330000    0.0169

# %%
# 4. Scaler data

# Sử dụng MinMaxScaler để chuẩn hóa dữ liệu
price = data['Price'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# %%
# 5. Chia train test
# Chia dữ liệu thành train và test
train_size = int(len(price_scaled) * 0.9)
test_size = len(price_scaled) - train_size
train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:]

# Hàm để tạo dataset
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:i + look_back, 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Sử dụng look_back để tạo tập huấn luyện và tập kiểm tra
look_back = 30
X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

# Định hình lại X_train và X_test cho mô hình LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Kiểm tra hình dạng của dữ liệu
print(f'X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}')
print(f'X_test shape: {X_test.shape}, Y_test shape: {Y_test.shape}')
# Out:
# X_train shape: (1151, 30, 1), Y_train shape: (1151,)
# X_test shape: (102, 30, 1), Y_test shape: (102,)

# %%
#6. Xây dựng mô hình và train mô hình
model = Sequential()

# Add convolutional layers
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(look_back, 1)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=1, kernel_size=3, activation='relu'))

# Add global average pooling layer
model.add(GlobalAveragePooling1D())

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 17s 188ms/step - loss: 0.0310 - val_loss: 0.0505
# Epoch 2/100
# 18/18 [==============================] - 1s 56ms/step - loss: 0.0082 - val_loss: 0.0147
# Epoch 3/100
# 18/18 [==============================] - 1s 75ms/step - loss: 0.0074 - val_loss: 0.0131
# Epoch 4/100
# 18/18 [==============================] - 1s 66ms/step - loss: 0.0072 - val_loss: 0.0134
# Epoch 5/100
# 18/18 [==============================] - 2s 129ms/step - loss: 0.0069 - val_loss: 0.0143
# Epoch 6/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.0066 - val_loss: 0.0089
# Epoch 7/100
# 18/18 [==============================] - 1s 85ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 8/100
# 18/18 [==============================] - 1s 69ms/step - loss: 0.0063 - val_loss: 0.0310
# Epoch 9/100
# 18/18 [==============================] - 1s 67ms/step - loss: 0.0057 - val_loss: 0.0061
# Epoch 10/100
# 18/18 [==============================] - 1s 51ms/step - loss: 0.0050 - val_loss: 0.0070
# Epoch 11/100
# 18/18 [==============================] - 1s 60ms/step - loss: 0.0043 - val_loss: 0.0084
# Epoch 12/100
# 18/18 [==============================] - 1s 58ms/step - loss: 0.0049 - val_loss: 0.0311
# Epoch 13/100
# 18/18 [==============================] - 1s 67ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 14/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0036 - val_loss: 0.0088
# Epoch 15/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.0034 - val_loss: 0.0095
# Epoch 16/100
# 18/18 [==============================] - 2s 94ms/step - loss: 0.0033 - val_loss: 0.0179
# Epoch 17/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.0029 - val_loss: 0.0128
# Epoch 18/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.0030 - val_loss: 0.0224
# Epoch 19/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.0028 - val_loss: 0.0052
# Epoch 20/100
# 18/18 [==============================] - 1s 80ms/step - loss: 0.0033 - val_loss: 0.0061
# Epoch 21/100
# 18/18 [==============================] - 1s 76ms/step - loss: 0.0031 - val_loss: 0.0049
# Epoch 22/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.0032 - val_loss: 0.0153
# Epoch 23/100
# 18/18 [==============================] - 1s 76ms/step - loss: 0.0026 - val_loss: 0.0053
# Epoch 24/100
# 18/18 [==============================] - 1s 50ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 25/100
# 18/18 [==============================] - 1s 59ms/step - loss: 0.0030 - val_loss: 0.0096
# Epoch 26/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.0025 - val_loss: 0.0084
# Epoch 27/100
# 18/18 [==============================] - 1s 77ms/step - loss: 0.0024 - val_loss: 0.0080
# Epoch 28/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0023 - val_loss: 0.0085
# Epoch 29/100
# 18/18 [==============================] - 1s 69ms/step - loss: 0.0025 - val_loss: 0.0129
# Epoch 30/100
# 18/18 [==============================] - 1s 84ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 31/100
# 18/18 [==============================] - 1s 56ms/step - loss: 0.0025 - val_loss: 0.0088
# Epoch 32/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 33/100
# 18/18 [==============================] - 1s 73ms/step - loss: 0.0024 - val_loss: 0.0258
# Epoch 34/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.0027 - val_loss: 0.0098
# Epoch 35/100
# 18/18 [==============================] - 2s 93ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 36/100
# 18/18 [==============================] - 1s 80ms/step - loss: 0.0025 - val_loss: 0.0105
# Epoch 37/100
# 18/18 [==============================] - 1s 78ms/step - loss: 0.0024 - val_loss: 0.0128
# Epoch 38/100
# 18/18 [==============================] - 1s 60ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 39/100
# 18/18 [==============================] - 1s 85ms/step - loss: 0.0024 - val_loss: 0.0056
# Epoch 40/100
# 18/18 [==============================] - 1s 59ms/step - loss: 0.0021 - val_loss: 0.0063
# Epoch 41/100
# 18/18 [==============================] - 1s 69ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 42/100
# 18/18 [==============================] - 1s 76ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 43/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0021 - val_loss: 0.0103
# Epoch 44/100
# 18/18 [==============================] - 1s 74ms/step - loss: 0.0021 - val_loss: 0.0122
# Epoch 45/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 46/100
# 18/18 [==============================] - 1s 75ms/step - loss: 0.0025 - val_loss: 0.0089
# Epoch 47/100
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0022 - val_loss: 0.0093
# Epoch 48/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 49/100
# 18/18 [==============================] - 1s 60ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 50/100
# 18/18 [==============================] - 1s 60ms/step - loss: 0.0023 - val_loss: 0.0036
# Epoch 51/100
# 18/18 [==============================] - 1s 69ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 52/100
# 18/18 [==============================] - 1s 58ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 53/100
# 18/18 [==============================] - 1s 68ms/step - loss: 0.0020 - val_loss: 0.0060
# Epoch 54/100
# 18/18 [==============================] - 1s 75ms/step - loss: 0.0021 - val_loss: 0.0112
# Epoch 55/100
# 18/18 [==============================] - 1s 74ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 56/100
# 18/18 [==============================] - 1s 68ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 57/100
# 18/18 [==============================] - 1s 76ms/step - loss: 0.0021 - val_loss: 0.0100
# Epoch 58/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 59/100
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0022 - val_loss: 0.0127
# Epoch 60/100
# 18/18 [==============================] - 1s 74ms/step - loss: 0.0020 - val_loss: 0.0087
# Epoch 61/100
# 18/18 [==============================] - 1s 76ms/step - loss: 0.0019 - val_loss: 0.0071
# Epoch 62/100
# 18/18 [==============================] - 1s 71ms/step - loss: 0.0019 - val_loss: 0.0094
# Epoch 63/100
# 18/18 [==============================] - 1s 66ms/step - loss: 0.0020 - val_loss: 0.0080
# Epoch 64/100
# 18/18 [==============================] - 1s 76ms/step - loss: 0.0021 - val_loss: 0.0043
# Epoch 65/100
# 18/18 [==============================] - 1s 69ms/step - loss: 0.0025 - val_loss: 0.0159
# Epoch 66/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.0023 - val_loss: 0.0107
# Epoch 67/100
# 18/18 [==============================] - 1s 68ms/step - loss: 0.0021 - val_loss: 0.0138
# Epoch 68/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0020 - val_loss: 0.0049
# Epoch 69/100
# 18/18 [==============================] - 1s 72ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 70/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.0019 - val_loss: 0.0062
# Epoch 71/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.0019 - val_loss: 0.0100
# Epoch 72/100
# 18/18 [==============================] - 1s 59ms/step - loss: 0.0018 - val_loss: 0.0066
# Epoch 73/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 74/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 75/100
# 18/18 [==============================] - 1s 71ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 76/100
# 18/18 [==============================] - 1s 60ms/step - loss: 0.0020 - val_loss: 0.0047
# Epoch 77/100
# 18/18 [==============================] - 1s 52ms/step - loss: 0.0018 - val_loss: 0.0086
# Epoch 78/100
# 18/18 [==============================] - 1s 67ms/step - loss: 0.0018 - val_loss: 0.0127
# Epoch 79/100
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0018 - val_loss: 0.0056
# Epoch 80/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 81/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 82/100
# 18/18 [==============================] - 1s 74ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 83/100
# 18/18 [==============================] - 1s 60ms/step - loss: 0.0022 - val_loss: 0.0056
# Epoch 84/100
# 18/18 [==============================] - 1s 59ms/step - loss: 0.0018 - val_loss: 0.0051
# Epoch 85/100
# 18/18 [==============================] - 1s 68ms/step - loss: 0.0018 - val_loss: 0.0144
# Epoch 86/100
# 18/18 [==============================] - 1s 86ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 87/100
# 18/18 [==============================] - 1s 75ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 88/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.0017 - val_loss: 0.0066
# Epoch 89/100
# 18/18 [==============================] - 1s 77ms/step - loss: 0.0017 - val_loss: 0.0081
# Epoch 90/100
# 18/18 [==============================] - 1s 73ms/step - loss: 0.0018 - val_loss: 0.0067
# Epoch 91/100
# 18/18 [==============================] - 1s 73ms/step - loss: 0.0019 - val_loss: 0.0097
# Epoch 92/100
# 18/18 [==============================] - 1s 73ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 93/100
# 18/18 [==============================] - 1s 71ms/step - loss: 0.0017 - val_loss: 0.0065
# Epoch 94/100
# 18/18 [==============================] - 1s 76ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 95/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0020 - val_loss: 0.0080
# Epoch 96/100
# 18/18 [==============================] - 1s 69ms/step - loss: 0.0017 - val_loss: 0.0045
# Epoch 97/100
# 18/18 [==============================] - 1s 79ms/step - loss: 0.0019 - val_loss: 0.0053
# Epoch 98/100
# 18/18 [==============================] - 1s 70ms/step - loss: 0.0018 - val_loss: 0.0080
# Epoch 99/100
# 18/18 [==============================] - 1s 69ms/step - loss: 0.0019 - val_loss: 0.0161
# Epoch 100/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0018 - val_loss: 0.0068

# %%
# 7. Dự báo trên tập test
test_predict = model.predict(X_test)

test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 4/4 [==============================] - 7s 27ms/step

# %%
# 8. Dự báo giá trị 30 ngày trong tương lai
last_30_days = price_scaled[-30:]
next_30_days = []
for i in range(30):
    x = last_30_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat)
    last_30_days = np.append(last_30_days, y_hat, axis=0)

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

print(next_30_days)
# Out:
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 365ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 138ms/step
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 257ms/step
# [[46194.055]
#  [45487.855]
#  [44707.832]
#  [44032.   ]
#  [43497.234]
#  [43220.   ]
#  [43085.555]
#  [43110.26 ]
#  [43010.48 ]
#  [42640.46 ]
#  [42117.402]
#  [41443.05 ]
#  [40646.914]
#  [39810.723]
#  [38946.37 ]
#  [38085.027]
#  [37214.867]
#  [36187.734]
#  [35145.754]
#  [34268.105]
#  [33469.81 ]
#  [32822.508]
#  [32275.67 ]
#  [31856.729]
#  [31536.111]
#  [31226.598]
#  [30842.299]
#  [30303.959]
#  [29569.787]
#  [28719.172]]

# %%
# 9. Dự báo giá trị 60 ngày trong tương lai
last_60_days = price_scaled[-60:]
next_60_days = []
for i in range(60):
    x = last_60_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_60_days.append(y_hat)
    last_60_days = np.append(last_30_days, y_hat, axis=0)

next_60_days = np.array(next_60_days).reshape(-1, 1)
next_60_days = scaler.inverse_transform(next_60_days)

print(next_60_days)
# Out:
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 1s 525ms/step
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 375ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 272ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 366ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 375ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 472ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 278ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 143ms/step
# [[46194.055]
#  [29007.027]
#  [27268.713]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]]

# %%
#10. Dự báo giá trị 90 ngày trong tương lai
last_90_days = price_scaled[-60:]
next_90_days = []
for i in range(90):
    x = last_90_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_90_days.append(y_hat)
    last_90_days = np.append(last_30_days, y_hat, axis=0)

next_90_days = np.array(next_90_days).reshape(-1, 1)
next_90_days = scaler.inverse_transform(next_90_days)

print(next_60_days)
# Out:
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 274ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 1s 532ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 360ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 367ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 152ms/step
# [[46194.055]
#  [29007.027]
#  [27268.713]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]
#  [27119.477]]

# %%
test_predict_df = pd.DataFrame(test_predict)
test_predict_index = range(len(train_data)+look_back, len(train_data)+look_back+len(test_predict))
test_predict_df.index = test_predict_index

next_30_days_df = pd.DataFrame(next_30_days)
next_30_index = range(len(data), len(data)+len(next_30_days))
next_30_days_df.index = next_30_index

next_60_days_df = pd.DataFrame(next_60_days)
next_60_index = range(len(data), len(data)+len(next_60_days))
next_60_days_df.index = next_60_index

next_90_days_df = pd.DataFrame(next_90_days)
next_90_index = range(len(data), len(data)+len(next_90_days))
next_90_days_df.index = next_90_index

train_data_df = data[:train_size][['Price']]
test_data_df = data[train_size:train_size + test_size][['Price']]

# %%
#11. Vẽ đồ thị các giá trị từ train tới test và dự đoán 30 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_30_days_df, label='Next 30 days')
plt.legend()
plt.show()

# %%
#12. Vẽ đồ thị các giá trị từ train tới test và dự đoán 60 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_60_days_df, label='Next 60 days')
plt.legend()
plt.show()

# %%
#13. Vẽ đồ thị các giá trị từ train tới test và dự đoán 90 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_90_days_df, label='Next 90 days')
plt.legend()
plt.show()

# %%
#14. Đánh giá mô hình
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mae = mean_absolute_error(Y_test[0], test_predict[:, 0])
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0])

print('RMSE :', test_score_rmse)
print('MAE :', test_score_mae)
print('MAPE :', test_score_mape)
# Out:
# RMSE : 2552.379905745414
# MAE : 2247.3583792892155
# MAPE : 0.044625075772492855
