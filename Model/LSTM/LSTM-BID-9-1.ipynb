# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# Read the dataset
df = pd.read_csv('../../Dataset/BID-Historical-Data_Group-9.csv',index_col='Date', parse_dates=True)
df.dropna() #Drop missing value
df = df.sort_values(by='Date', ascending=True)
df =df.reset_index(drop=True) #Reset the index

# %%
# Hàm chuyển đổi
def convert_str_to_number(str):
    return float(str.replace(',', ''))

def convert_change_to_number(change_str):
    return float(change_str.strip('%')) / 100

def convert_volume_to_number(volume_str):
    factor = {'K': 1000, 'M': 1000000, 'B': 1000000000}
    return int(float(volume_str[:-1]) * factor[volume_str[-1]]) if volume_str[-1] in factor else int(volume_str)

# Áp dụng hàm chuyển đổi cho các cột giá trị
df['Price'], df['Open'], df['High'], df['Low'] = [df[col].apply(convert_str_to_number) for col in ['Price', 'Open', 'High', 'Low']]
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df["Vol."] = df["Vol."].apply(convert_volume_to_number)

print(df)
# Out:
#         Price     Open     High      Low     Vol.  Change %
# 0     25141.5  24950.2  25332.9  24950.2  1450000    0.0108
# 1     25715.5  25332.9  25830.3  25256.3  1150000    0.0228
# 2     26480.9  25409.4  27016.6  25409.4  5300000    0.0298
# 3     26595.7  26480.9  26710.5  26327.8  2009999    0.0043
# 4     26710.5  26787.0  26978.3  26557.4  2140000    0.0043
# ...       ...      ...      ...      ...      ...       ...
# 1308  48900.0  49400.0  49400.0  48550.0   763200   -0.0061
# 1309  49100.0  49000.0  49200.0  48600.0  1230000    0.0041
# 1310  48600.0  49450.0  49450.0  48600.0  1390000   -0.0102
# 1311  47700.0  48400.0  48500.0  47400.0  2089999   -0.0185
# 1312  47100.0  47700.0  48300.0  47100.0  1970000   -0.0126
#
# [1313 rows x 6 columns]

# %%
price=df.reset_index()['Price']
price
# Out:
# 0       25141.5
# 1       25715.5
# 2       26480.9
# 3       26595.7
# 4       26710.5
#          ...
# 1308    48900.0
# 1309    49100.0
# 1310    48600.0
# 1311    47700.0
# 1312    47100.0
# Name: Price, Length: 1313, dtype: float64

# %%
plt.plot(price)

# %% [markdown]
# ## LSTM are sentitive to the scale of the data => apply MinMax schaler

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
price_scaled=scaler.fit_transform(np.array(price).reshape(-1,1))

# %%
# 4. split the data into train and test
train_size = int(0.9 * len(price_scaled))
test_size = len(price_scaled) - train_size 

train_data = price_scaled[0:train_size,:]
test_data = price_scaled[train_size:len(price_scaled),:1]

# %%
#Training process
# a. convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]  
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# Sử dụng look_back để tạo tập huấn luyện và tập kiểm tra
time_step = 30
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# c. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# Kiểm tra hình dạng của dữ liệu
print(f'X_train shape: {X_train.shape}, Y_train shape: {y_train.shape}')
print(f'X_test shape: {X_test.shape}, Y_test shape: {y_test.shape}')
# Out:
# X_train shape: (1150, 30, 1), Y_train shape: (1150,)
# X_test shape: (101, 30, 1), Y_test shape: (101,)

# %%
X_train.shape[1]
# Out:
# 30

# %%
#6. Xây dựng mô hình và train mô hình
model=Sequential()
model.add(LSTM(64, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1))

# Compile model
model.compile(loss='mean_squared_error',optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# d:\install package\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - loss: 0.0778 - val_loss: 0.0225
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0061 - val_loss: 0.0114
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0042 - val_loss: 0.0151
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0030 - val_loss: 0.0049
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0016 - val_loss: 0.0048
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0015 - val_loss: 0.0041
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0011 - val_loss: 0.0027
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0010 - val_loss: 0.0025
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0010 - val_loss: 0.0037
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.8560e-04 - val_loss: 0.0015
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.9867e-04 - val_loss: 0.0016
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.4669e-04 - val_loss: 0.0017
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.4399e-04 - val_loss: 0.0016
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.6743e-04 - val_loss: 0.0015
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 9.2822e-04 - val_loss: 0.0020
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.1353e-04 - val_loss: 0.0016
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 9.6184e-04 - val_loss: 0.0014
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 9.2951e-04 - val_loss: 0.0014
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.4086e-04 - val_loss: 0.0013
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.5755e-04 - val_loss: 0.0014
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 8.6642e-04 - val_loss: 0.0021
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.1460e-04 - val_loss: 0.0017
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.6638e-04 - val_loss: 0.0024
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.9179e-04 - val_loss: 0.0020
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.1000e-04 - val_loss: 0.0015
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 8.5687e-04 - val_loss: 0.0015
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.4019e-04 - val_loss: 0.0012
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.8375e-04 - val_loss: 0.0016
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.3601e-04 - val_loss: 0.0013
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.6283e-04 - val_loss: 0.0013
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.4880e-04 - val_loss: 0.0017
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 8.5964e-04 - val_loss: 0.0015
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.4485e-04 - val_loss: 0.0013
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.8253e-04 - val_loss: 0.0014
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.7321e-04 - val_loss: 0.0011
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.3495e-04 - val_loss: 0.0016
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.4759e-04 - val_loss: 0.0012
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.4314e-04 - val_loss: 0.0012
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.5065e-04 - val_loss: 0.0011
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.3338e-04 - val_loss: 0.0011
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.0690e-04 - val_loss: 0.0010
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.5434e-04 - val_loss: 0.0012
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.0726e-04 - val_loss: 0.0011
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.6749e-04 - val_loss: 0.0014
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.6221e-04 - val_loss: 0.0017
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.6947e-04 - val_loss: 0.0010
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.9121e-04 - val_loss: 0.0010
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.1549e-04 - val_loss: 0.0010
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.7756e-04 - val_loss: 0.0019
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.8489e-04 - val_loss: 0.0010
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.2487e-04 - val_loss: 0.0011
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.7268e-04 - val_loss: 9.8796e-04
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.7103e-04 - val_loss: 0.0011
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.5553e-04 - val_loss: 0.0020
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.9539e-04 - val_loss: 0.0012
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.5390e-04 - val_loss: 0.0010
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.0563e-04 - val_loss: 0.0010
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.5421e-04 - val_loss: 9.6609e-04
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.8936e-04 - val_loss: 9.8013e-04
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.7493e-04 - val_loss: 0.0011

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,885 (198.77 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 33,924 (132.52 KB)

# %%
# 7. Dự báo trên tập test
y_pred=model.predict(X_test)

y_pred=scaler.inverse_transform(y_pred)

##Transformback to original form
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step

# %%
# 12. Dự báo 30 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_30 = []
n_steps = 100
i = 0

while i < 30:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_30.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_30.extend(yhat.tolist())
        i = i + 1

next_30_days = scaler.inverse_transform(lst_output_30)
# Out:
# [[46831.52823809]
#  [46410.30633366]
#  [46033.88988754]
#  [45624.34391919]
#  [45186.58587566]
#  [44734.91199246]
#  [44276.7362951 ]
#  [43814.95976344]
#  [43350.97472006]
#  [42885.97774991]
#  [42421.18759692]
#  [41957.89871484]
#  [41497.37416556]
#  [41040.89732337]
#  [40589.71093774]
#  [40145.03929234]
#  [39708.09189817]
#  [39280.02840856]
#  [38861.97246845]
#  [38454.99601853]
#  [38060.0971362 ]
#  [37678.20095889]
#  [37310.13290863]
#  [36956.62330846]
#  [36618.2778372 ]
#  [36295.59322532]
#  [35988.93694256]
#  [35698.54812127]
#  [35424.54401939]
#  [35166.91725057]]

# %%
# 12. Dự báo 60 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_60 = []
n_steps = 100
i = 0

while i < 60:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_60.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_60.extend(yhat.tolist())
        i = i + 1

next_60_days = scaler.inverse_transform(lst_output_60)
# Out:
# [[46831.52823809]
#  [46410.30633366]
#  [46033.88988754]
#  [45624.34391919]
#  [45186.58587566]
#  [44734.91199246]
#  [44276.7362951 ]
#  [43814.95976344]
#  [43350.97472006]
#  [42885.97774991]
#  [42421.18759692]
#  [41957.89871484]
#  [41497.37416556]
#  [41040.89732337]
#  [40589.71093774]
#  [40145.03929234]
#  [39708.09189817]
#  [39280.02840856]
#  [38861.97246845]
#  [38454.99601853]
#  [38060.0971362 ]
#  [37678.20095889]
#  [37310.13290863]
#  [36956.62330846]
#  [36618.2778372 ]
#  [36295.59322532]
#  [35988.93694256]
#  [35698.54812127]
#  [35424.54401939]
#  [35166.91725057]
#  [34925.54132399]
#  [34700.17987718]
#  [34490.5032953 ]
#  [34296.08963445]
#  [34116.43477781]
#  [33950.97459468]
#  [33799.09232678]
#  [33660.1315143 ]
#  [33533.40799873]
#  [33418.21730915]
#  [33313.84481844]
#  [33219.57959266]
#  [33134.71900746]
#  [33058.57428788]
#  [32990.47697133]
#  [32929.78444739]
#  [32875.87995777]
#  [32828.17074974]
#  [32786.113005  ]
#  [32749.18229434]
#  [32716.88558045]
#  [32688.77691385]
#  [32664.43158075]
#  [32643.45995241]
#  [32625.50563857]
#  [32610.23810109]
#  [32597.35911705]
#  [32586.5889293 ]
#  [32577.68471235]
#  [32570.42118324]]

# %%
# 12. Dự báo 90 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_90 = []
n_steps = 100
i = 0

while i < 90:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_90.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_90.extend(yhat.tolist())
        i = i + 1

next_90_days = scaler.inverse_transform(lst_output_90)
# Out:
# [[46831.52823809]
#  [46410.30633366]
#  [46033.88988754]
#  [45624.34391919]
#  [45186.58587566]
#  [44734.91199246]
#  [44276.7362951 ]
#  [43814.95976344]
#  [43350.97472006]
#  [42885.97774991]
#  [42421.18759692]
#  [41957.89871484]
#  [41497.37416556]
#  [41040.89732337]
#  [40589.71093774]
#  [40145.03929234]
#  [39708.09189817]
#  [39280.02840856]
#  [38861.97246845]
#  [38454.99601853]
#  [38060.0971362 ]
#  [37678.20095889]
#  [37310.13290863]
#  [36956.62330846]
#  [36618.2778372 ]
#  [36295.59322532]
#  [35988.93694256]
#  [35698.54812127]
#  [35424.54401939]
#  [35166.91725057]
#  [34925.54132399]
#  [34700.17987718]
#  [34490.5032953 ]
#  [34296.08963445]
#  [34116.43477781]
#  [33950.97459468]
#  [33799.09232678]
#  [33660.1315143 ]
#  [33533.40799873]
#  [33418.21730915]
#  [33313.84481844]
#  [33219.57959266]
#  [33134.71900746]
#  [33058.57428788]
#  [32990.47697133]
#  [32929.78444739]
#  [32875.87995777]
#  [32828.17074974]
#  [32786.113005  ]
#  [32749.18229434]
#  [32716.88558045]
#  [32688.77691385]
#  [32664.43158075]
#  [32643.45995241]
#  [32625.50563857]
#  [32610.23810109]
#  [32597.35911705]
#  [32586.5889293 ]
#  [32577.68471235]
#  [32570.42118324]
#  [32564.59152482]
#  [32560.01754196]
#  [32556.52750255]
#  [32553.97921981]
#  [32552.24343301]
#  [32551.19734448]
#  [32550.73569906]
#  [32550.7717074 ]
#  [32551.2158103 ]
#  [32552.00891714]
#  [32553.0827044 ]
#  [32554.37623487]
#  [32555.84519061]
#  [32557.45356327]
#  [32559.16257463]
#  [32560.93990952]
#  [32562.76156236]
#  [32564.59891115]
#  [32566.44272298]
#  [32568.27083886]
#  [32570.07125601]
#  [32571.83751141]
#  [32573.55852555]
#  [32575.22968198]
#  [32576.83897793]
#  [32578.39195314]
#  [32579.88491444]
#  [32581.30678235]
#  [32582.66863635]
#  [32583.96770658]]

# %%
# 15. Vẽ hình dự báo 30 ngày tiếp theo

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))

test_data_index = pd.RangeIndex(start=train_size+time_step+1, stop=train_size+test_size, step=1)
plt.plot(test_data_index, (y_pred))

predict_data_index_90 = pd.RangeIndex(start=len(price)-1, stop=len(price)+89, step=1)
plt.plot(predict_data_index_90,next_90_days, color='purple')
predict_data_index_60 = pd.RangeIndex(start=len(price)-1, stop=len(price)+59, step=1)
plt.plot(predict_data_index_60,next_60_days, color='red')
predict_data_index_30 = pd.RangeIndex(start=len(price)-1, stop=len(price)+29, step=1)
plt.plot(predict_data_index_30,next_30_days, color='green')
plt.legend(['Test','Predict','Predict90days', 'Predict60days', 'Predict30days'])

plt.show()

# %%
# 12. Đánh giá độ chính xác thuật toán 
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Testing RMSE:', test_rmse)

from sklearn.metrics import mean_absolute_error
test_mae = mean_absolute_error(y_test, y_pred)
print('Testing MAE:', test_mae)

from sklearn.metrics import mean_absolute_percentage_error
test_mape = mean_absolute_percentage_error(y_test, y_pred)
print('Testing MAPE:', test_mape)
# Out:
# Testing RMSE: 1024.1498401323406
# Testing MAE: 733.4890934405939
# Testing MAPE: 0.014659457303161753
