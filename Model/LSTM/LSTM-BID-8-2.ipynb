# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# Read the dataset
df = pd.read_csv('../../Dataset/BID-Historical-Data_Group-9.csv',index_col='Date', parse_dates=True)
df.dropna() #Drop missing value
df = df.sort_values(by='Date', ascending=True)
df =df.reset_index(drop=True) #Reset the index

# %%
# Hàm chuyển đổi
def convert_str_to_number(str):
    return float(str.replace(',', ''))

def convert_change_to_number(change_str):
    return float(change_str.strip('%')) / 100

def convert_volume_to_number(volume_str):
    factor = {'K': 1000, 'M': 1000000, 'B': 1000000000}
    return int(float(volume_str[:-1]) * factor[volume_str[-1]]) if volume_str[-1] in factor else int(volume_str)

# Áp dụng hàm chuyển đổi cho các cột giá trị
df['Price'], df['Open'], df['High'], df['Low'] = [df[col].apply(convert_str_to_number) for col in ['Price', 'Open', 'High', 'Low']]
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df["Vol."] = df["Vol."].apply(convert_volume_to_number)

print(df)
# Out:
#         Price     Open     High      Low     Vol.  Change %
# 0     25141.5  24950.2  25332.9  24950.2  1450000    0.0108
# 1     25715.5  25332.9  25830.3  25256.3  1150000    0.0228
# 2     26480.9  25409.4  27016.6  25409.4  5300000    0.0298
# 3     26595.7  26480.9  26710.5  26327.8  2009999    0.0043
# 4     26710.5  26787.0  26978.3  26557.4  2140000    0.0043
# ...       ...      ...      ...      ...      ...       ...
# 1308  48900.0  49400.0  49400.0  48550.0   763200   -0.0061
# 1309  49100.0  49000.0  49200.0  48600.0  1230000    0.0041
# 1310  48600.0  49450.0  49450.0  48600.0  1390000   -0.0102
# 1311  47700.0  48400.0  48500.0  47400.0  2089999   -0.0185
# 1312  47100.0  47700.0  48300.0  47100.0  1970000   -0.0126
#
# [1313 rows x 6 columns]

# %%
price=df.reset_index()['Price']
price
# Out:
# 0       25141.5
# 1       25715.5
# 2       26480.9
# 3       26595.7
# 4       26710.5
#          ...
# 1308    48900.0
# 1309    49100.0
# 1310    48600.0
# 1311    47700.0
# 1312    47100.0
# Name: Price, Length: 1313, dtype: float64

# %%
plt.plot(price)

# %% [markdown]
# ## LSTM are sentitive to the scale of the data => apply MinMax schaler

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
price_scaled=scaler.fit_transform(np.array(price).reshape(-1,1))

# %%
# 4. split the data into train and test
train_size = int(0.8 * len(price_scaled))
test_size = len(price_scaled) - train_size 

train_data = price_scaled[0:train_size,:]
test_data = price_scaled[train_size:len(price_scaled),:1]

# %%
#Training process
# a. convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]  
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# Sử dụng look_back để tạo tập huấn luyện và tập kiểm tra
time_step = 30
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# c. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# Kiểm tra hình dạng của dữ liệu
print(f'X_train shape: {X_train.shape}, Y_train shape: {y_train.shape}')
print(f'X_test shape: {X_test.shape}, Y_test shape: {y_test.shape}')
# Out:
# X_train shape: (1019, 30, 1), Y_train shape: (1019,)
# X_test shape: (232, 30, 1), Y_test shape: (232,)

# %%
X_train.shape[1]
# Out:
# 30

# %%
#6. Xây dựng mô hình và train mô hình
model=Sequential()
model.add(LSTM(64, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1))

# Compile model
model.compile(loss='mean_squared_error',optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# d:\install package\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0675 - val_loss: 0.0030
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0056 - val_loss: 0.0210
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 9.8327e-04
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.6994e-04 - val_loss: 0.0022
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 0.0036
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011 - val_loss: 9.5340e-04
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.6695e-04 - val_loss: 0.0012
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.6477e-04 - val_loss: 9.0110e-04
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.5954e-04 - val_loss: 0.0011
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.0071e-04 - val_loss: 8.5779e-04
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.4992e-04 - val_loss: 8.6101e-04
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.2687e-04 - val_loss: 0.0010
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.4753e-04 - val_loss: 8.4597e-04
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2026e-04 - val_loss: 0.0011
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 8.3571e-04
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.2202e-04 - val_loss: 8.3079e-04
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5415e-04 - val_loss: 8.1656e-04
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1148e-04 - val_loss: 9.0375e-04
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9571e-04 - val_loss: 9.3461e-04
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7427e-04 - val_loss: 8.0234e-04
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.4017e-04 - val_loss: 8.4578e-04
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.4830e-04 - val_loss: 8.0292e-04
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.8527e-04 - val_loss: 8.5642e-04
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.8933e-04 - val_loss: 0.0012
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.9498e-04 - val_loss: 0.0011
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.3933e-04 - val_loss: 8.0690e-04
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7129e-04 - val_loss: 7.9836e-04
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3346e-04 - val_loss: 8.5318e-04
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.6516e-04 - val_loss: 9.4009e-04
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.6436e-04 - val_loss: 7.6746e-04
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.1016e-04 - val_loss: 0.0012
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.3008e-04 - val_loss: 8.1798e-04
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0143e-04 - val_loss: 9.4966e-04
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7319e-04 - val_loss: 9.7820e-04
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.3509e-04 - val_loss: 0.0012
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.2809e-04 - val_loss: 0.0014
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.7377e-04 - val_loss: 0.0014
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.9478e-04 - val_loss: 7.4267e-04
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.5673e-04 - val_loss: 9.1407e-04
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.1242e-04 - val_loss: 0.0013
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.6522e-04 - val_loss: 8.7064e-04
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.7300e-04 - val_loss: 8.2361e-04
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4358e-04 - val_loss: 8.9834e-04
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.4544e-04 - val_loss: 7.6324e-04
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.0996e-04 - val_loss: 7.2066e-04
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4292e-04 - val_loss: 8.1572e-04
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5529e-04 - val_loss: 0.0011
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.3627e-04 - val_loss: 7.2272e-04
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.1143e-04 - val_loss: 7.8141e-04
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.0681e-04 - val_loss: 7.5679e-04
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.7061e-04 - val_loss: 9.1322e-04
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.8451e-04 - val_loss: 7.0991e-04
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.6293e-04 - val_loss: 8.1453e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4768e-04 - val_loss: 7.6330e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.0333e-04 - val_loss: 8.9793e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5404e-04 - val_loss: 7.1459e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.3783e-04 - val_loss: 6.8355e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.8792e-04 - val_loss: 7.7287e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.3305e-04 - val_loss: 0.0010
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.1408e-04 - val_loss: 9.7771e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2647e-04 - val_loss: 8.1036e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.2085e-04 - val_loss: 0.0016
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.9093e-04 - val_loss: 7.4751e-04

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,885 (198.77 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 33,924 (132.52 KB)

# %%
# 7. Dự báo trên tập test
y_pred=model.predict(X_test)

y_pred=scaler.inverse_transform(y_pred)

##Transformback to original form
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
# 12. Dự báo 30 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_30 = []
n_steps = 100
i = 0

while i < 30:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_30.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_30.extend(yhat.tolist())
        i = i + 1

next_30_days = scaler.inverse_transform(lst_output_30)        

print(next_30_days)
# Out:
# [[46930.31481916]
#  [46544.16319433]
#  [46193.60443172]
#  [45852.64789394]
#  [45511.55101594]
#  [45166.34734026]
#  [44815.98616189]
#  [44460.87372881]
#  [44102.06628576]
#  [43740.82320145]
#  [43378.3632198 ]
#  [43015.75181845]
#  [42653.92521432]
#  [42293.67743754]
#  [41935.67325753]
#  [41580.5257394 ]
#  [41228.79993716]
#  [40881.01474026]
#  [40537.69088474]
#  [40199.31956133]
#  [39866.38457444]
#  [39539.36049557]
#  [39218.69235089]
#  [38904.82147345]
#  [38598.14303172]
#  [38299.04850101]
#  [38007.87395921]
#  [37724.94440469]
#  [37450.52759179]
#  [37184.87003918]]

# %%
# 12. Dự báo 60 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_60 = []
n_steps = 100
i = 0

while i < 60:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_60.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_60.extend(yhat.tolist())
        i = i + 1

next_60_days = scaler.inverse_transform(lst_output_60)        
print(next_60_days)
# Out:
# [[46930.31481916]
#  [46544.16319433]
#  [46193.60443172]
#  [45852.64789394]
#  [45511.55101594]
#  [45166.34734026]
#  [44815.98616189]
#  [44460.87372881]
#  [44102.06628576]
#  [43740.82320145]
#  [43378.3632198 ]
#  [43015.75181845]
#  [42653.92521432]
#  [42293.67743754]
#  [41935.67325753]
#  [41580.5257394 ]
#  [41228.79993716]
#  [40881.01474026]
#  [40537.69088474]
#  [40199.31956133]
#  [39866.38457444]
#  [39539.36049557]
#  [39218.69235089]
#  [38904.82147345]
#  [38598.14303172]
#  [38299.04850101]
#  [38007.87395921]
#  [37724.94440469]
#  [37450.52759179]
#  [37184.87003918]
#  [36928.16748451]
#  [36680.57411735]
#  [36442.2108888 ]
#  [36213.14704569]
#  [35993.42413609]
#  [35783.03662026]
#  [35581.94387341]
#  [35390.0674158 ]
#  [35207.29829913]
#  [35033.49156673]
#  [34868.46902347]
#  [34712.03770155]
#  [34563.97693446]
#  [34424.04112685]
#  [34291.97545043]
#  [34167.50384124]
#  [34050.34377228]
#  [33940.20625351]
#  [33836.79029213]
#  [33739.78289253]
#  [33648.89691125]
#  [33563.81658283]
#  [33484.25291723]
#  [33409.90492164]
#  [33340.48729917]
#  [33275.71844614]
#  [33215.31583552]
#  [33159.0301788 ]
#  [33106.59095176]
#  [33057.76917826]]

# %%
# 12. Dự báo 90 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_90 = []
n_steps = 100
i = 0

while i < 90:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_90.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_90.extend(yhat.tolist())
        i = i + 1

next_90_days = scaler.inverse_transform(lst_output_90)        
print(next_90_days)
# Out:
# [[46930.31481916]
#  [46544.16319433]
#  [46193.60443172]
#  [45852.64789394]
#  [45511.55101594]
#  [45166.34734026]
#  [44815.98616189]
#  [44460.87372881]
#  [44102.06628576]
#  [43740.82320145]
#  [43378.3632198 ]
#  [43015.75181845]
#  [42653.92521432]
#  [42293.67743754]
#  [41935.67325753]
#  [41580.5257394 ]
#  [41228.79993716]
#  [40881.01474026]
#  [40537.69088474]
#  [40199.31956133]
#  [39866.38457444]
#  [39539.36049557]
#  [39218.69235089]
#  [38904.82147345]
#  [38598.14303172]
#  [38299.04850101]
#  [38007.87395921]
#  [37724.94440469]
#  [37450.52759179]
#  [37184.87003918]
#  [36928.16748451]
#  [36680.57411735]
#  [36442.2108888 ]
#  [36213.14704569]
#  [35993.42413609]
#  [35783.03662026]
#  [35581.94387341]
#  [35390.0674158 ]
#  [35207.29829913]
#  [35033.49156673]
#  [34868.46902347]
#  [34712.03770155]
#  [34563.97693446]
#  [34424.04112685]
#  [34291.97545043]
#  [34167.50384124]
#  [34050.34377228]
#  [33940.20625351]
#  [33836.79029213]
#  [33739.78289253]
#  [33648.89691125]
#  [33563.81658283]
#  [33484.25291723]
#  [33409.90492164]
#  [33340.48729917]
#  [33275.71844614]
#  [33215.31583552]
#  [33159.0301788 ]
#  [33106.59095176]
#  [33057.76917826]
#  [33012.32018623]
#  [32970.02423245]
#  [32930.6708066 ]
#  [32894.06047787]
#  [32859.99381542]
#  [32828.30370362]
#  [32798.81748708]
#  [32771.37543647]
#  [32745.82982527]
#  [32722.04031326]
#  [32699.87671643]
#  [32679.21900699]
#  [32659.95639001]
#  [32641.97899389]
#  [32625.19448955]
#  [32609.5114712 ]
#  [32594.84037961]
#  [32581.11289127]
#  [32568.24775659]
#  [32556.18311507]
#  [32544.86079939]
#  [32534.22356552]
#  [32524.21601601]
#  [32514.79106303]
#  [32505.91085164]
#  [32497.52737074]
#  [32489.60922842]
#  [32482.11764647]
#  [32475.02861933]
#  [32468.30429208]]

# %%
# 15. Vẽ hình dự báo 30 ngày tiếp theo

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))

test_data_index = pd.RangeIndex(start=train_size+time_step+1, stop=train_size+test_size, step=1)
plt.plot(test_data_index, (y_pred))

predict_data_index_90 = pd.RangeIndex(start=len(price)-1, stop=len(price)+89, step=1)
plt.plot(predict_data_index_90,next_90_days, color='purple')
predict_data_index_60 = pd.RangeIndex(start=len(price)-1, stop=len(price)+59, step=1)
plt.plot(predict_data_index_60,next_60_days, color='red')
predict_data_index_30 = pd.RangeIndex(start=len(price)-1, stop=len(price)+29, step=1)
plt.plot(predict_data_index_30,next_30_days, color='green')
plt.legend(['Test','Predict','Predict90days', 'Predict60days', 'Predict30days'])

plt.show()

# %%
# 12. Đánh giá độ chính xác thuật toán 
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Testing RMSE:', test_rmse)

from sklearn.metrics import mean_absolute_error
test_mae = mean_absolute_error(y_test, y_pred)
print('Testing MAE:', test_mae)

from sklearn.metrics import mean_absolute_percentage_error
test_mape = mean_absolute_percentage_error(y_test, y_pred)
print('Testing MAPE:', test_mape)
# Out:
# Testing RMSE: 847.0286262092984
# Testing MAE: 606.8657731681035
# Testing MAPE: 0.013657010312188763
